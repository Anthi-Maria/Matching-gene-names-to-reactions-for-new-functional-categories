# %%
import numpy as np
import pandas as pd
import cobra.test
import os
from os.path import join

from time import time

a= cobra.io.read_sbml_model("iEC1344_C.xml")

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7f4f47451790>,
#             <Reaction 12PPDStex at 0x7f4f47451820>,
#             <Reaction 23CAMPtex at 0x7f4f47451be0>,
#             <Reaction 23CCMPtex at 0x7f4f47451f70>,
#             <Reaction 23CGMPtex at 0x7f4f47451fa0>,
#             <Reaction 23CUMPtex at 0x7f4f474518e0>,
#             <Reaction 23DAPPAtex at 0x7f4f47451e50>,
#             <Reaction 26DAHtex at 0x7f4f47460bb0>,
#             <Reaction 34dhpactex at 0x7f4f47427940>,
#             <Reaction 3AMPtex at 0x7f4f47427f40>,
#             <Reaction 3CMPtex at 0x7f4f47427a00>,
#             <Reaction 3GMPtex at 0x7f4f47419f70>,
#             <Reaction 3HPPtex at 0x7f4f473c5df0>,
#             <Reaction 3PEPTtex at 0x7f4f47388d30>,
#             <Reaction 3UMPtex at 0x7f4f473936d0>,
#             <Reaction 3hoxpactex at 0x7f4f46568c40>,
#             <Reaction 4HOXPACDtex at 0x7f4f47393f40>,
#             <Reaction 4PEPTtex at 0x7f4f473b0f70>,
#             <Reaction 4hoxpactex at 0x7f4f46568dc0>,
#             <Reaction 5DGLCNtex at 0x7f4f473bd940>,
#             <Reaction 5MTRtex at 0x7f4f473bd610>,
#             <Reaction 6APAt1 at 0x7f4f46514be0>,
#             <Reaction ABUTtex at 0x7f4f473c5ee0>,
#             <Reaction ACACtex at 0x7f4f473dffa0>,
#             <Reaction ACALDtex at 0x7f4f473fad60>,
#             <Reaction ACGAL1Ptex at 0x7f4f473ee970>,
#             <Reaction ACGALtex at 0x7f4f47388bb0>,
#             <Reaction ACGAM1Ptex at 0x7f4f47388e80>,
#             <Reaction ACGAtex at 0x7f4f47393bb0>,
#             <Reaction ACMANAtex at 0x7f4f473939a0>,
#             <Reaction ACMUMtex at 0x7f4f473bdb50>,
#             <Reaction ACSERtex at 0x7f4f47379ee0>,
#             <Reaction ACtex at 0x7f4f473098e0>,
#             <Reaction ADEtex at 0x7f4f47318e50>,
#             <Reaction AGMtex at 0x7f4f4ef91a90>,
#             <Reaction AKGtex at 0x7f4f4736b8e0>,
#             <Reaction ALAALAtex at 0x7f4f4736b820>,
#             <Reaction ALAtex at 0x7f4f47327cd0>,
#             <Reaction ALLTNtex at 0x7f4f4ef6fc40>,
#             <Reaction ALLtex at 0x7f4f4ef79160>,
#             <Reaction AMPtex at 0x7f4f4ec03610>,
#             <Reaction ANHGMtex at 0x7f4f4ef95af0>,
#             <Reaction ARBTtex at 0x7f4f471b4fa0>,
#             <Reaction ARBtex at 0x7f4f4710d910>,
#             <Reaction ARGtex at 0x7f4f470f1f40>,
#             <Reaction ASCBtex at 0x7f4f4700af70>,
#             <Reaction ASNtex at 0x7f4f46fb5a90>,
#             <Reaction ASO3tex at 0x7f4f46f59f10>,
#             <Reaction ASPtex at 0x7f4f4c1861c0>,
#             <Reaction BALAtex at 0x7f4f4c0ebd90>,
#             <Reaction BTNtex at 0x7f4f4c122df0>,
#             <Reaction BUTSO3tex at 0x7f4f4c0c3be0>,
#             <Reaction BUTtex at 0x7f4f472c7d30>,
#             <Reaction CA2tex at 0x7f4f47240e80>,
#             <Reaction CD2tex at 0x7f4f47260ac0>,
#             <Reaction CGLYtex at 0x7f4f4c115c40>,
#             <Reaction CHLtex at 0x7f4f4c115220>,
#             <Reaction CHTBStex at 0x7f4f4752cbe0>,
#             <Reaction CITtex at 0x7f4f4c0b8eb0>,
#             <Reaction CLBtex at 0x7f4f465bfa90>,
#             <Reaction CLtex at 0x7f4f472589a0>,
#             <Reaction CMPtex at 0x7f4f472b98e0>,
#             <Reaction CMtex at 0x7f4f47278dc0>,
#             <Reaction CO2tex at 0x7f4f47201bb0>,
#             <Reaction COBALT2tex at 0x7f4f4726ed60>,
#             <Reaction CRNDtex at 0x7f4f47221ac0>,
#             <Reaction CRNtex at 0x7f4f471c5700>,
#             <Reaction CSNtex at 0x7f4f471cdfd0>,
#             <Reaction CU2tex at 0x7f4f471f8df0>,
#             <Reaction CUtex at 0x7f4f471cda30>,
#             <Reaction CYANtex at 0x7f4f47187c10>,
#             <Reaction CYNTtex at 0x7f4f47187bb0>,
#             <Reaction CYSDtex at 0x7f4f47196ac0>,
#             <Reaction CYStex at 0x7f4f471a6d90>,
#             <Reaction CYTDtex at 0x7f4f47145f10>,
#             <Reaction DALAtex at 0x7f4f471cde80>,
#             <Reaction DAMPtex at 0x7f4f471d8bb0>,
#             <Reaction DAPtex at 0x7f4f471d8880>,
#             <Reaction DARBtex at 0x7f4f4644bc70>,
#             <Reaction DCAtex at 0x7f4f47187d30>,
#             <Reaction DCMPtex at 0x7f4f47187be0>,
#             <Reaction DDGLCNtex at 0x7f4f47196fa0>,
#             <Reaction DGMPtex at 0x7f4f471a6a90>,
#             <Reaction DGSNtex at 0x7f4f471b4ee0>,
#             <Reaction DHAtex at 0x7f4f47145670>,
#             <Reaction DIMPtex at 0x7f4f47168fd0>,
#             <Reaction DINStex at 0x7f4f47168e20>,
#             <Reaction DMSOtex at 0x7f4f47122be0>,
#             <Reaction DMStex at 0x7f4f47122d30>,
#             <Reaction DOPAtex at 0x7f4f47135d00>,
#             <Reaction DOXRBCNtex at 0x7f4f47135ee0>,
#             <Reaction DSERtex at 0x7f4f470ddc70>,
#             <Reaction DTMPtex at 0x7f4f470c8fd0>,
#             <Reaction DUMPtex at 0x7f4f470f1eb0>,
#             <Reaction D_LACtex at 0x7f4f471568b0>,
#             <Reaction ETHAtex at 0x7f4f470abee0>,
#             <Reaction ETHSO3tex at 0x7f4f47098910>,
#             <Reaction ETOHtex at 0x7f4f470f16a0>,
#             <Reaction F6Ptex at 0x7f4f47052f40>,
#             <Reaction FALDtex at 0x7f4f47076b80>,
#             <Reaction FE2tex at 0x7f4f46fd5e80>,
#             <Reaction FE3tex at 0x7f4f46f901f0>,
#             <Reaction FORtex at 0x7f4f46f90ee0>,
#             <Reaction FRULYStex at 0x7f4f46fa2be0>,
#             <Reaction FRUURtex at 0x7f4f46fb5c10>,
#             <Reaction FRUtex at 0x7f4f46fb54c0>,
#             <Reaction FUCtex at 0x7f4f46f49f70>,
#             <Reaction FUMtex at 0x7f4f46f59fa0>,
#             <Reaction FUSAtex at 0x7f4f46f49cd0>,
#             <Reaction G1Ptex at 0x7f4f46f594f0>,
#             <Reaction G3PCtex at 0x7f4f46f03fd0>,
#             <Reaction G3PEtex at 0x7f4f46f03eb0>,
#             <Reaction G3PGtex at 0x7f4f46f16d90>,
#             <Reaction G3PItex at 0x7f4f46f16c10>,
#             <Reaction G3PStex at 0x7f4f46f03c40>,
#             <Reaction G6Ptex at 0x7f4f46f39fa0>,
#             <Reaction GAL1Ptex at 0x7f4f46f39ac0>,
#             <Reaction GALAMtex at 0x7f4f46552fd0>,
#             <Reaction GALBDtex at 0x7f4f46f28f10>,
#             <Reaction GALCTNLtex at 0x7f4f46ecdb20>,
#             <Reaction GALCTNtex at 0x7f4f46ee1af0>,
#             <Reaction GALCTtex at 0x7f4f46ecda60>,
#             <Reaction GALTtex at 0x7f4f46ef50a0>,
#             <Reaction GALURtex at 0x7f4f46ef5d90>,
#             <Reaction GALtex at 0x7f4f46e9af10>,
#             <Reaction GAMAN6Ptex at 0x7f4f46e9abe0>,
#             <Reaction GAMtex at 0x7f4f46e9a7f0>,
#             <Reaction GBBTNtex at 0x7f4f46ebf8e0>,
#             <Reaction GDPtex at 0x7f4f46e55820>,
#             <Reaction GLCNtex at 0x7f4f46f39c70>,
#             <Reaction GLCRtex at 0x7f4f46ecdc40>,
#             <Reaction GLCUR1Ptex at 0x7f4f46ee1d00>,
#             <Reaction GLCURtex at 0x7f4f46ee1b80>,
#             <Reaction GLCtex_copy1 at 0x7f4f46ef52e0>,
#             <Reaction GLNtex at 0x7f4f46e889a0>,
#             <Reaction GLUtex at 0x7f4f46e55d00>,
#             <Reaction GLYALDtex at 0x7f4f46e69e50>,
#             <Reaction GLYBtex at 0x7f4f46ebfcd0>,
#             <Reaction GLYC2Ptex at 0x7f4f46e7d970>,
#             <Reaction GLYC3Ptex at 0x7f4f46e7df70>,
#             <Reaction GLYCAtex at 0x7f4f46e9acd0>,
#             <Reaction GLYCLTtex at 0x7f4f46e37eb0>,
#             <Reaction GLYCtex at 0x7f4f46daa4c0>,
#             <Reaction GLYtex at 0x7f4f46cde940>,
#             <Reaction GMPtex at 0x7f4f46c7afa0>,
#             <Reaction GSNtex at 0x7f4f46acfeb0>,
#             <Reaction GTHOXtex at 0x7f4f46a856a0>,
#             <Reaction GTHRDtex at 0x7f4f46a03f10>,
#             <Reaction GTPtex at 0x7f4f469edd90>,
#             <Reaction H2O2tex at 0x7f4f46e7dfd0>,
#             <Reaction H2Otex at 0x7f4f46e7de50>,
#             <Reaction H2Stex at 0x7f4f46e215e0>,
#             <Reaction H2tex at 0x7f4f46e21e80>,
#             <Reaction HCINNMtex at 0x7f4f46dda7f0>,
#             <Reaction HG2tex at 0x7f4f46d829a0>,
#             <Reaction HIStex at 0x7f4f46dbdf10>,
#             <Reaction HOMtex at 0x7f4f46d53d30>,
#             <Reaction HPPPNtex at 0x7f4f46d66580>,
#             <Reaction HXAtex at 0x7f4f46e21be0>,
#             <Reaction HYXNtex at 0x7f4f46e10be0>,
#             <Reaction Htex at 0x7f4f46e21b50>,
#             <Reaction IDONtex at 0x7f4f46d829d0>,
#             <Reaction ILEtex at 0x7f4f46d97d90>,
#             <Reaction IMPtex at 0x7f4f46daaf70>,
#             <Reaction INDOLEtex at 0x7f4f46d97ee0>,
#             <Reaction INSTtex at 0x7f4f46d53eb0>,
#             <Reaction ISETACtex at 0x7f4f46d79ee0>,
#             <Reaction Ktex at 0x7f4f46d0fe80>,
#             <Reaction LALADGLUtex at 0x7f4f46cca9a0>,
#             <Reaction LALALGLUtex at 0x7f4f46cdee50>,
#             <Reaction LCTStex at 0x7f4f46cefd00>,
#             <Reaction LEUtex at 0x7f4f46c97a60>,
#             <Reaction LIPOtex at 0x7f4f46c82f10>,
#             <Reaction LYStex at 0x7f4f46c67ee0>,
#             <Reaction LYXtex at 0x7f4f46c54eb0>,
#             <Reaction L_LACtex_copy1 at 0x7f4f46d21f40>,
#             <Reaction L_LACtex_copy2 at 0x7f4f46581d30>,
#             <Reaction MALDtex at 0x7f4f46c7aca0>,
#             <Reaction MALtex at 0x7f4f46c23640>,
#             <Reaction MAN6Ptex at 0x7f4f46c39e80>,
#             <Reaction MANGLYCtex at 0x7f4f46c7ad00>,
#             <Reaction MANtex at 0x7f4f46c10f10>,
#             <Reaction MELIBtex at 0x7f4f46bf0f40>,
#             <Reaction MEOHtex at 0x7f4f46bf0d60>,
#             <Reaction METDtex at 0x7f4f46b85e20>,
#             <Reaction METSOX1tex at 0x7f4f46b85eb0>,
#             <Reaction METSOX2tex at 0x7f4f46b85ee0>,
#             <Reaction METtex at 0x7f4f46bb0f40>,
#             <Reaction MG2tex at 0x7f4f46b9c490>,
#             <Reaction MINCYCtex at 0x7f4f46bde9a0>,
#             <Reaction MMETtex at 0x7f4f46bb0f10>,
#             <Reaction MNLtex at 0x7f4f46b44dc0>,
#             <Reaction MNtex at 0x7f4f46b44f70>,
#             <Reaction MOBDtex at 0x7f4f46bb0f70>,
#             <Reaction MSO3tex at 0x7f4f46b29d30>,
#             <Reaction N2Otex at 0x7f4f46b29d60>,
#             <Reaction NACtex at 0x7f4f46b6cf10>,
#             <Reaction NAtex at 0x7f4f46acff40>,
#             <Reaction NH4tex at 0x7f4f46ae2d30>,
#             <Reaction NI2tex at 0x7f4f46af2ca0>,
#             <Reaction NMNtex at 0x7f4f46a85fa0>,
#             <Reaction NO2tex at 0x7f4f46a42a00>,
#             <Reaction NO3tex at 0x7f4f46acfdf0>,
#             <Reaction NOtex at 0x7f4f46af2e20>,
#             <Reaction O2Stex at 0x7f4f469d7d60>,
#             <Reaction O2tex at 0x7f4f469ede50>,
#             <Reaction OCTAtex at 0x7f4f46a6bc40>,
#             <Reaction ORNtex at 0x7f4f469d7c70>,
#             <Reaction OROTtex at 0x7f4f469edeb0>,
#             <Reaction PACALDtex at 0x7f4f469ffbb0>,
#             <Reaction PACt1 at 0x7f4f4657ff10>,
#             <Reaction PEAMNtex at 0x7f4f469ffe80>,
#             <Reaction PENGt1 at 0x7f4f4657fc10>,
#             <Reaction PHEtex at 0x7f4f468f3a00>,
#             <Reaction PItex at 0x7f4f4688ae80>,
#             <Reaction PNTOtex at 0x7f4f465bf8b0>,
#             <Reaction PPALtex at 0x7f4f46568c70>,
#             <Reaction PPAtex at 0x7f4f4657f280>,
#             <Reaction PPPNtex at 0x7f4f464d2f70>,
#             <Reaction PPTtex at 0x7f4f464e6fa0>,
#             <Reaction PROGLYtex at 0x7f4f469187c0>,
#             <Reaction PROtex at 0x7f4f468f3df0>,
#             <Reaction PSCLYStex at 0x7f4f468f3f10>,
#             <Reaction PSERtex at 0x7f4f4688a7f0>,
#             <Reaction PTRCtex at 0x7f4f46860d90>,
#             <Reaction PYDAMtex at 0x7f4f46830bb0>,
#             <Reaction PYDXNtex at 0x7f4f4681ba30>,
#             <Reaction PYDXtex at 0x7f4f46830c40>,
#             <Reaction PYRtex at 0x7f4f468b5dc0>,
#             <Reaction QUIN2tex at 0x7f4f468b5850>,
#             <Reaction R5Ptex at 0x7f4f46860d30>,
#             <Reaction RAFFtex at 0x7f4f46568eb0>,
#             <Reaction RIBtex at 0x7f4f46808fa0>,
#             <Reaction RMNtex at 0x7f4f46872b50>,
#             <Reaction SALCNtex at 0x7f4f46552f40>,
#             <Reaction SBTtex at 0x7f4f467a77c0>,
#             <Reaction SELtex at 0x7f4f467bdf10>,
#             <Reaction SERtex at 0x7f4f467bd6d0>,
#             <Reaction SKMtex at 0x7f4f46724ca0>,
#             <Reaction SLNTtex at 0x7f4f46724e50>,
#             <Reaction SO2tex at 0x7f4f46737fa0>,
#             <Reaction SO3tex at 0x7f4f46737df0>,
#             <Reaction SO4tex at 0x7f4f466ccf40>,
#             <Reaction SPMDtex at 0x7f4f467ead60>,
#             <Reaction SUCCtex at 0x7f4f467a7e20>,
#             <Reaction SUCRtex at 0x7f4f467bdfd0>,
#             <Reaction SULFACtex at 0x7f4f4674ec70>,
#             <Reaction TARTRDtex at 0x7f4f46765fd0>,
#             <Reaction TARTRtex at 0x7f4f46765c70>,
#             <Reaction TAURtex at 0x7f4f4674ed30>,
#             <Reaction TCYNTtex at 0x7f4f4670dee0>,
#             <Reaction THMDtex at 0x7f4f46737b50>,
#             <Reaction THMtex at 0x7f4f466cce20>,
#             <Reaction THRPtex at 0x7f4f466debe0>,
#             <Reaction THRtex at 0x7f4f46688bb0>,
#             <Reaction THYMtex at 0x7f4f466def70>,
#             <Reaction TMAOtex at 0x7f4f4669e3d0>,
#             <Reaction TMAtex at 0x7f4f4669eeb0>,
#             <Reaction TREtex at 0x7f4f46670d90>,
#             <Reaction TRPtex at 0x7f4f46604a90>,
#             <Reaction TSULtex at 0x7f4f46619d00>,
#             <Reaction TTRCYCtex at 0x7f4f46619f40>,
#             <Reaction TUNGStex at 0x7f4f4662ec40>,
#             <Reaction TYMtex at 0x7f4f4662ec70>,
#             <Reaction TYRPtex at 0x7f4f465d7d00>,
#             <Reaction TYRtex at 0x7f4f466e78e0>,
#             <Reaction UACGAMtex at 0x7f4f46688e20>,
#             <Reaction UDPACGALtex at 0x7f4f466b2a90>,
#             <Reaction UDPGALtex at 0x7f4f46658d90>,
#             <Reaction UDPGLCURtex at 0x7f4f46658fa0>,
#             <Reaction UDPGtex at 0x7f4f46670c70>,
#             <Reaction UMPtex at 0x7f4f4662efa0>,
#             <Reaction URAtex at 0x7f4f465c17c0>,
#             <Reaction UREAtex at 0x7f4f465d7940>,
#             <Reaction VALtex at 0x7f4f46619e80>,
#             <Reaction XANtex at 0x7f4f465d7fa0>,
#             <Reaction XMPtex at 0x7f4f46581be0>,
#             <Reaction XTSNtex at 0x7f4f46581fd0>,
#             <Reaction XYLUtex at 0x7f4f46581940>,
#             <Reaction XYLtex at 0x7f4f465a9d00>,
#             <Reaction Zn2tex at 0x7f4f465a9d90>})}

# %%
i= -1

J=list()
C=list()
J.append(a.genes[0].name)
C.append(a.genes[0].reactions)

dictionary = dict(zip(J, C))

while i <1344:
   
    J= list()
    C= list()
    
    J.append(a.genes[i].name)
    C.append(a.genes[i].reactions)

    dictionary2 = dict(zip(J, C))
    dictionary.update(dictionary2)
    
    i=i+1

dictionary
# Out:
# {'PhoE': frozenset({<Reaction 12PPDRtex at 0x7f4f47451790>,
#             <Reaction 12PPDStex at 0x7f4f47451820>,
#             <Reaction 23CAMPtex at 0x7f4f47451be0>,
#             <Reaction 23CCMPtex at 0x7f4f47451f70>,
#             <Reaction 23CGMPtex at 0x7f4f47451fa0>,
#             <Reaction 23CUMPtex at 0x7f4f474518e0>,
#             <Reaction 23DAPPAtex at 0x7f4f47451e50>,
#             <Reaction 26DAHtex at 0x7f4f47460bb0>,
#             <Reaction 34dhpactex at 0x7f4f47427940>,
#             <Reaction 3AMPtex at 0x7f4f47427f40>,
#             <Reaction 3CMPtex at 0x7f4f47427a00>,
#             <Reaction 3GMPtex at 0x7f4f47419f70>,
#             <Reaction 3HPPtex at 0x7f4f473c5df0>,
#             <Reaction 3PEPTtex at 0x7f4f47388d30>,
#             <Reaction 3UMPtex at 0x7f4f473936d0>,
#             <Reaction 3hoxpactex at 0x7f4f46568c40>,
#             <Reaction 4HOXPACDtex at 0x7f4f47393f40>,
#             <Reaction 4PEPTtex at 0x7f4f473b0f70>,
#             <Reaction 4hoxpactex at 0x7f4f46568dc0>,
#             <Reaction 5DGLCNtex at 0x7f4f473bd940>,
#             <Reaction 5MTRtex at 0x7f4f473bd610>,
#             <Reaction 6APAt1 at 0x7f4f46514be0>,
#             <Reaction ABUTtex at 0x7f4f473c5ee0>,
#             <Reaction ACACtex at 0x7f4f473dffa0>,
#             <Reaction ACALDtex at 0x7f4f473fad60>,
#             <Reaction ACGAL1Ptex at 0x7f4f473ee970>,
#             <Reaction ACGALtex at 0x7f4f47388bb0>,
#             <Reaction ACGAM1Ptex at 0x7f4f47388e80>,
#             <Reaction ACGAtex at 0x7f4f47393bb0>,
#             <Reaction ACMANAtex at 0x7f4f473939a0>,
#             <Reaction ACMUMtex at 0x7f4f473bdb50>,
#             <Reaction ACSERtex at 0x7f4f47379ee0>,
#             <Reaction ACtex at 0x7f4f473098e0>,
#             <Reaction ADEtex at 0x7f4f47318e50>,
#             <Reaction AGMtex at 0x7f4f4ef91a90>,
#             <Reaction AKGtex at 0x7f4f4736b8e0>,
#             <Reaction ALAALAtex at 0x7f4f4736b820>,
#             <Reaction ALAtex at 0x7f4f47327cd0>,
#             <Reaction ALLTNtex at 0x7f4f4ef6fc40>,
#             <Reaction ALLtex at 0x7f4f4ef79160>,
#             <Reaction AMPtex at 0x7f4f4ec03610>,
#             <Reaction ANHGMtex at 0x7f4f4ef95af0>,
#             <Reaction ARBTtex at 0x7f4f471b4fa0>,
#             <Reaction ARBtex at 0x7f4f4710d910>,
#             <Reaction ARGtex at 0x7f4f470f1f40>,
#             <Reaction ASCBtex at 0x7f4f4700af70>,
#             <Reaction ASNtex at 0x7f4f46fb5a90>,
#             <Reaction ASO3tex at 0x7f4f46f59f10>,
#             <Reaction ASPtex at 0x7f4f4c1861c0>,
#             <Reaction BALAtex at 0x7f4f4c0ebd90>,
#             <Reaction BTNtex at 0x7f4f4c122df0>,
#             <Reaction BUTSO3tex at 0x7f4f4c0c3be0>,
#             <Reaction BUTtex at 0x7f4f472c7d30>,
#             <Reaction CA2tex at 0x7f4f47240e80>,
#             <Reaction CD2tex at 0x7f4f47260ac0>,
#             <Reaction CGLYtex at 0x7f4f4c115c40>,
#             <Reaction CHLtex at 0x7f4f4c115220>,
#             <Reaction CHTBStex at 0x7f4f4752cbe0>,
#             <Reaction CITtex at 0x7f4f4c0b8eb0>,
#             <Reaction CLBtex at 0x7f4f465bfa90>,
#             <Reaction CLtex at 0x7f4f472589a0>,
#             <Reaction CMPtex at 0x7f4f472b98e0>,
#             <Reaction CMtex at 0x7f4f47278dc0>,
#             <Reaction CO2tex at 0x7f4f47201bb0>,
#             <Reaction COBALT2tex at 0x7f4f4726ed60>,
#             <Reaction CRNDtex at 0x7f4f47221ac0>,
#             <Reaction CRNtex at 0x7f4f471c5700>,
#             <Reaction CSNtex at 0x7f4f471cdfd0>,
#             <Reaction CU2tex at 0x7f4f471f8df0>,
#             <Reaction CUtex at 0x7f4f471cda30>,
#             <Reaction CYANtex at 0x7f4f47187c10>,
#             <Reaction CYNTtex at 0x7f4f47187bb0>,
#             <Reaction CYSDtex at 0x7f4f47196ac0>,
#             <Reaction CYStex at 0x7f4f471a6d90>,
#             <Reaction CYTDtex at 0x7f4f47145f10>,
#             <Reaction DALAtex at 0x7f4f471cde80>,
#             <Reaction DAMPtex at 0x7f4f471d8bb0>,
#             <Reaction DAPtex at 0x7f4f471d8880>,
#             <Reaction DARBtex at 0x7f4f4644bc70>,
#             <Reaction DCAtex at 0x7f4f47187d30>,
#             <Reaction DCMPtex at 0x7f4f47187be0>,
#             <Reaction DDGLCNtex at 0x7f4f47196fa0>,
#             <Reaction DGMPtex at 0x7f4f471a6a90>,
#             <Reaction DGSNtex at 0x7f4f471b4ee0>,
#             <Reaction DHAtex at 0x7f4f47145670>,
#             <Reaction DIMPtex at 0x7f4f47168fd0>,
#             <Reaction DINStex at 0x7f4f47168e20>,
#             <Reaction DMSOtex at 0x7f4f47122be0>,
#             <Reaction DMStex at 0x7f4f47122d30>,
#             <Reaction DOPAtex at 0x7f4f47135d00>,
#             <Reaction DOXRBCNtex at 0x7f4f47135ee0>,
#             <Reaction DSERtex at 0x7f4f470ddc70>,
#             <Reaction DTMPtex at 0x7f4f470c8fd0>,
#             <Reaction DUMPtex at 0x7f4f470f1eb0>,
#             <Reaction D_LACtex at 0x7f4f471568b0>,
#             <Reaction ETHAtex at 0x7f4f470abee0>,
#             <Reaction ETHSO3tex at 0x7f4f47098910>,
#             <Reaction ETOHtex at 0x7f4f470f16a0>,
#             <Reaction F6Ptex at 0x7f4f47052f40>,
#             <Reaction FALDtex at 0x7f4f47076b80>,
#             <Reaction FE2tex at 0x7f4f46fd5e80>,
#             <Reaction FE3tex at 0x7f4f46f901f0>,
#             <Reaction FORtex at 0x7f4f46f90ee0>,
#             <Reaction FRULYStex at 0x7f4f46fa2be0>,
#             <Reaction FRUURtex at 0x7f4f46fb5c10>,
#             <Reaction FRUtex at 0x7f4f46fb54c0>,
#             <Reaction FUCtex at 0x7f4f46f49f70>,
#             <Reaction FUMtex at 0x7f4f46f59fa0>,
#             <Reaction FUSAtex at 0x7f4f46f49cd0>,
#             <Reaction G1Ptex at 0x7f4f46f594f0>,
#             <Reaction G3PCtex at 0x7f4f46f03fd0>,
#             <Reaction G3PEtex at 0x7f4f46f03eb0>,
#             <Reaction G3PGtex at 0x7f4f46f16d90>,
#             <Reaction G3PItex at 0x7f4f46f16c10>,
#             <Reaction G3PStex at 0x7f4f46f03c40>,
#             <Reaction G6Ptex at 0x7f4f46f39fa0>,
#             <Reaction GAL1Ptex at 0x7f4f46f39ac0>,
#             <Reaction GALAMtex at 0x7f4f46552fd0>,
#             <Reaction GALBDtex at 0x7f4f46f28f10>,
#             <Reaction GALCTNLtex at 0x7f4f46ecdb20>,
#             <Reaction GALCTNtex at 0x7f4f46ee1af0>,
#             <Reaction GALCTtex at 0x7f4f46ecda60>,
#             <Reaction GALTtex at 0x7f4f46ef50a0>,
#             <Reaction GALURtex at 0x7f4f46ef5d90>,
#             <Reaction GALtex at 0x7f4f46e9af10>,
#             <Reaction GAMAN6Ptex at 0x7f4f46e9abe0>,
#             <Reaction GAMtex at 0x7f4f46e9a7f0>,
#             <Reaction GBBTNtex at 0x7f4f46ebf8e0>,
#             <Reaction GDPtex at 0x7f4f46e55820>,
#             <Reaction GLCNtex at 0x7f4f46f39c70>,
#             <Reaction GLCRtex at 0x7f4f46ecdc40>,
#             <Reaction GLCUR1Ptex at 0x7f4f46ee1d00>,
#             <Reaction GLCURtex at 0x7f4f46ee1b80>,
#             <Reaction GLCtex_copy1 at 0x7f4f46ef52e0>,
#             <Reaction GLNtex at 0x7f4f46e889a0>,
#             <Reaction GLUtex at 0x7f4f46e55d00>,
#             <Reaction GLYALDtex at 0x7f4f46e69e50>,
#             <Reaction GLYBtex at 0x7f4f46ebfcd0>,
#             <Reaction GLYC2Ptex at 0x7f4f46e7d970>,
#             <Reaction GLYC3Ptex at 0x7f4f46e7df70>,
#             <Reaction GLYCAtex at 0x7f4f46e9acd0>,
#             <Reaction GLYCLTtex at 0x7f4f46e37eb0>,
#             <Reaction GLYCtex at 0x7f4f46daa4c0>,
#             <Reaction GLYtex at 0x7f4f46cde940>,
#             <Reaction GMPtex at 0x7f4f46c7afa0>,
#             <Reaction GSNtex at 0x7f4f46acfeb0>,
#             <Reaction GTHOXtex at 0x7f4f46a856a0>,
#             <Reaction GTHRDtex at 0x7f4f46a03f10>,
#             <Reaction GTPtex at 0x7f4f469edd90>,
#             <Reaction H2O2tex at 0x7f4f46e7dfd0>,
#             <Reaction H2Otex at 0x7f4f46e7de50>,
#             <Reaction H2Stex at 0x7f4f46e215e0>,
#             <Reaction H2tex at 0x7f4f46e21e80>,
#             <Reaction HCINNMtex at 0x7f4f46dda7f0>,
#             <Reaction HG2tex at 0x7f4f46d829a0>,
#             <Reaction HIStex at 0x7f4f46dbdf10>,
#             <Reaction HOMtex at 0x7f4f46d53d30>,
#             <Reaction HPPPNtex at 0x7f4f46d66580>,
#             <Reaction HXAtex at 0x7f4f46e21be0>,
#             <Reaction HYXNtex at 0x7f4f46e10be0>,
#             <Reaction Htex at 0x7f4f46e21b50>,
#             <Reaction IDONtex at 0x7f4f46d829d0>,
#             <Reaction ILEtex at 0x7f4f46d97d90>,
#             <Reaction IMPtex at 0x7f4f46daaf70>,
#             <Reaction INDOLEtex at 0x7f4f46d97ee0>,
#             <Reaction INSTtex at 0x7f4f46d53eb0>,
#             <Reaction ISETACtex at 0x7f4f46d79ee0>,
#             <Reaction Ktex at 0x7f4f46d0fe80>,
#             <Reaction LALADGLUtex at 0x7f4f46cca9a0>,
#             <Reaction LALALGLUtex at 0x7f4f46cdee50>,
#             <Reaction LCTStex at 0x7f4f46cefd00>,
#             <Reaction LEUtex at 0x7f4f46c97a60>,
#             <Reaction LIPOtex at 0x7f4f46c82f10>,
#             <Reaction LYStex at 0x7f4f46c67ee0>,
#             <Reaction LYXtex at 0x7f4f46c54eb0>,
#             <Reaction L_LACtex_copy1 at 0x7f4f46d21f40>,
#             <Reaction L_LACtex_copy2 at 0x7f4f46581d30>,
#             <Reaction MALDtex at 0x7f4f46c7aca0>,
#             <Reaction MALtex at 0x7f4f46c23640>,
#             <Reaction MAN6Ptex at 0x7f4f46c39e80>,
#             <Reaction MANGLYCtex at 0x7f4f46c7ad00>,
#             <Reaction MANtex at 0x7f4f46c10f10>,
#             <Reaction MELIBtex at 0x7f4f46bf0f40>,
#             <Reaction MEOHtex at 0x7f4f46bf0d60>,
#             <Reaction METDtex at 0x7f4f46b85e20>,
#             <Reaction METSOX1tex at 0x7f4f46b85eb0>,
#             <Reaction METSOX2tex at 0x7f4f46b85ee0>,
#             <Reaction METtex at 0x7f4f46bb0f40>,
#             <Reaction MG2tex at 0x7f4f46b9c490>,
#             <Reaction MINCYCtex at 0x7f4f46bde9a0>,
#             <Reaction MMETtex at 0x7f4f46bb0f10>,
#             <Reaction MNLtex at 0x7f4f46b44dc0>,
#             <Reaction MNtex at 0x7f4f46b44f70>,
#             <Reaction MOBDtex at 0x7f4f46bb0f70>,
#             <Reaction MSO3tex at 0x7f4f46b29d30>,
#             <Reaction N2Otex at 0x7f4f46b29d60>,
#             <Reaction NACtex at 0x7f4f46b6cf10>,
#             <Reaction NAtex at 0x7f4f46acff40>,
#             <Reaction NH4tex at 0x7f4f46ae2d30>,
#             <Reaction NI2tex at 0x7f4f46af2ca0>,
#             <Reaction NMNtex at 0x7f4f46a85fa0>,
#             <Reaction NO2tex at 0x7f4f46a42a00>,
#             <Reaction NO3tex at 0x7f4f46acfdf0>,
#             <Reaction NOtex at 0x7f4f46af2e20>,
#             <Reaction O2Stex at 0x7f4f469d7d60>,
#             <Reaction O2tex at 0x7f4f469ede50>,
#             <Reaction OCTAtex at 0x7f4f46a6bc40>,
#             <Reaction ORNtex at 0x7f4f469d7c70>,
#             <Reaction OROTtex at 0x7f4f469edeb0>,
#             <Reaction PACALDtex at 0x7f4f469ffbb0>,
#             <Reaction PACt1 at 0x7f4f4657ff10>,
#             <Reaction PEAMNtex at 0x7f4f469ffe80>,
#             <Reaction PENGt1 at 0x7f4f4657fc10>,
#             <Reaction PHEtex at 0x7f4f468f3a00>,
#             <Reaction PItex at 0x7f4f4688ae80>,
#             <Reaction PNTOtex at 0x7f4f465bf8b0>,
#             <Reaction PPALtex at 0x7f4f46568c70>,
#             <Reaction PPAtex at 0x7f4f4657f280>,
#             <Reaction PPPNtex at 0x7f4f464d2f70>,
#             <Reaction PPTtex at 0x7f4f464e6fa0>,
#             <Reaction PROGLYtex at 0x7f4f469187c0>,
#             <Reaction PROtex at 0x7f4f468f3df0>,
#             <Reaction PSCLYStex at 0x7f4f468f3f10>,
#             <Reaction PSERtex at 0x7f4f4688a7f0>,
#             <Reaction PTRCtex at 0x7f4f46860d90>,
#             <Reaction PYDAMtex at 0x7f4f46830bb0>,
#             <Reaction PYDXNtex at 0x7f4f4681ba30>,
#             <Reaction PYDXtex at 0x7f4f46830c40>,
#             <Reaction PYRtex at 0x7f4f468b5dc0>,
#             <Reaction QUIN2tex at 0x7f4f468b5850>,
#             <Reaction R5Ptex at 0x7f4f46860d30>,
#             <Reaction RAFFtex at 0x7f4f46568eb0>,
#             <Reaction RIBtex at 0x7f4f46808fa0>,
#             <Reaction RMNtex at 0x7f4f46872b50>,
#             <Reaction SALCNtex at 0x7f4f46552f40>,
#             <Reaction SBTtex at 0x7f4f467a77c0>,
#             <Reaction SELtex at 0x7f4f467bdf10>,
#             <Reaction SERtex at 0x7f4f467bd6d0>,
#             <Reaction SKMtex at 0x7f4f46724ca0>,
#             <Reaction SLNTtex at 0x7f4f46724e50>,
#             <Reaction SO2tex at 0x7f4f46737fa0>,
#             <Reaction SO3tex at 0x7f4f46737df0>,
#             <Reaction SO4tex at 0x7f4f466ccf40>,
#             <Reaction SPMDtex at 0x7f4f467ead60>,
#             <Reaction SUCCtex at 0x7f4f467a7e20>,
#             <Reaction SUCRtex at 0x7f4f467bdfd0>,
#             <Reaction SULFACtex at 0x7f4f4674ec70>,
#             <Reaction TARTRDtex at 0x7f4f46765fd0>,
#             <Reaction TARTRtex at 0x7f4f46765c70>,
#             <Reaction TAURtex at 0x7f4f4674ed30>,
#             <Reaction TCYNTtex at 0x7f4f4670dee0>,
#             <Reaction THMDtex at 0x7f4f46737b50>,
#             <Reaction THMtex at 0x7f4f466cce20>,
#             <Reaction THRPtex at 0x7f4f466debe0>,
#             <Reaction THRtex at 0x7f4f46688bb0>,
#             <Reaction THYMtex at 0x7f4f466def70>,
#             <Reaction TMAOtex at 0x7f4f4669e3d0>,
#             <Reaction TMAtex at 0x7f4f4669eeb0>,
#             <Reaction TREtex at 0x7f4f46670d90>,
#             <Reaction TRPtex at 0x7f4f46604a90>,
#             <Reaction TSULtex at 0x7f4f46619d00>,
#             <Reaction TTRCYCtex at 0x7f4f46619f40>,
#             <Reaction TUNGStex at 0x7f4f4662ec40>,
#             <Reaction TYMtex at 0x7f4f4662ec70>,
#             <Reaction TYRPtex at 0x7f4f465d7d00>,
#             <Reaction TYRtex at 0x7f4f466e78e0>,
#             <Reaction UACGAMtex at 0x7f4f46688e20>,
#             <Reaction UDPACGALtex at 0x7f4f466b2a90>,
#             <Reaction UDPGALtex at 0x7f4f46658d90>,
#             <Reaction UDPGLCURtex at 0x7f4f46658fa0>,
#             <Reaction UDPGtex at 0x7f4f46670c70>,
#             <Reaction UMPtex at 0x7f4f4662efa0>,
#             <Reaction URAtex at 0x7f4f465c17c0>,
#             <Reaction UREAtex at 0x7f4f465d7940>,
#             <Reaction VALtex at 0x7f4f46619e80>,
#             <Reaction XANtex at 0x7f4f465d7fa0>,
#             <Reaction XMPtex at 0x7f4f46581be0>,
#             <Reaction XTSNtex at 0x7f4f46581fd0>,
#             <Reaction XYLUtex at 0x7f4f46581940>,
#             <Reaction XYLtex at 0x7f4f465a9d00>,
#             <Reaction Zn2tex at 0x7f4f465a9d90>}),
#  'YlbA': frozenset({<Reaction UGCIAMH at 0x7f4f4642f8b0>}),
#  'OmpC': frozenset({<Reaction 12PPDRtex at 0x7f4f47451790>,
#             <Reaction 12PPDStex at 0x7f4f47451820>,
#             <Reaction 23CAMPtex at 0x7f4f47451be0>,
#             <Reaction 23CCMPtex at 0x7f4f47451f70>,
#             <Reaction 23CGMPtex at 0x7f4f47451fa0>,
#             <Reaction 23CUMPtex at 0x7f4f474518e0>,
#             <Reaction 23DAPPAtex at 0x7f4f47451e50>,
#             <Reaction 26DAHtex at 0x7f4f47460bb0>,
#             <Reaction 34dhpactex at 0x7f4f47427940>,
#             <Reaction 3AMPtex at 0x7f4f47427f40>,
#             <Reaction 3CMPtex at 0x7f4f47427a00>,
#             <Reaction 3GMPtex at 0x7f4f47419f70>,
#             <Reaction 3HPPtex at 0x7f4f473c5df0>,
#             <Reaction 3PEPTtex at 0x7f4f47388d30>,
#             <Reaction 3UMPtex at 0x7f4f473936d0>,
#             <Reaction 3hoxpactex at 0x7f4f46568c40>,
#             <Reaction 4HOXPACDtex at 0x7f4f47393f40>,
#             <Reaction 4PEPTtex at 0x7f4f473b0f70>,
#             <Reaction 4hoxpactex at 0x7f4f46568dc0>,
#             <Reaction 5DGLCNtex at 0x7f4f473bd940>,
#             <Reaction 5MTRtex at 0x7f4f473bd610>,
#             <Reaction 6APAt1 at 0x7f4f46514be0>,
#             <Reaction ABUTtex at 0x7f4f473c5ee0>,
#             <Reaction ACACtex at 0x7f4f473dffa0>,
#             <Reaction ACALDtex at 0x7f4f473fad60>,
#             <Reaction ACGAL1Ptex at 0x7f4f473ee970>,
#             <Reaction ACGALtex at 0x7f4f47388bb0>,
#             <Reaction ACGAM1Ptex at 0x7f4f47388e80>,
#             <Reaction ACGAtex at 0x7f4f47393bb0>,
#             <Reaction ACMANAtex at 0x7f4f473939a0>,
#             <Reaction ACMUMtex at 0x7f4f473bdb50>,
#             <Reaction ACNAMtex at 0x7f4f473b06a0>,
#             <Reaction ACSERtex at 0x7f4f47379ee0>,
#             <Reaction ACtex at 0x7f4f473098e0>,
#             <Reaction ADEtex at 0x7f4f47318e50>,
#             <Reaction AGMtex at 0x7f4f4ef91a90>,
#             <Reaction AKGtex at 0x7f4f4736b8e0>,
#             <Reaction ALAALAtex at 0x7f4f4736b820>,
#             <Reaction ALAtex at 0x7f4f47327cd0>,
#             <Reaction ALLTNtex at 0x7f4f4ef6fc40>,
#             <Reaction ALLtex at 0x7f4f4ef79160>,
#             <Reaction AMPtex at 0x7f4f4ec03610>,
#             <Reaction ANHGMtex at 0x7f4f4ef95af0>,
#             <Reaction ARBTtex at 0x7f4f471b4fa0>,
#             <Reaction ARBtex at 0x7f4f4710d910>,
#             <Reaction ARGtex at 0x7f4f470f1f40>,
#             <Reaction ASCBtex at 0x7f4f4700af70>,
#             <Reaction ASNtex at 0x7f4f46fb5a90>,
#             <Reaction ASO3tex at 0x7f4f46f59f10>,
#             <Reaction ASPtex at 0x7f4f4c1861c0>,
#             <Reaction BALAtex at 0x7f4f4c0ebd90>,
#             <Reaction BTNtex at 0x7f4f4c122df0>,
#             <Reaction BUTSO3tex at 0x7f4f4c0c3be0>,
#             <Reaction BUTtex at 0x7f4f472c7d30>,
#             <Reaction CA2tex at 0x7f4f47240e80>,
#             <Reaction CD2tex at 0x7f4f47260ac0>,
#             <Reaction CGLYtex at 0x7f4f4c115c40>,
#             <Reaction CHLtex at 0x7f4f4c115220>,
#             <Reaction CHTBStex at 0x7f4f4752cbe0>,
#             <Reaction CITtex at 0x7f4f4c0b8eb0>,
#             <Reaction CLBtex at 0x7f4f465bfa90>,
#             <Reaction CLtex at 0x7f4f472589a0>,
#             <Reaction CMPtex at 0x7f4f472b98e0>,
#             <Reaction CMtex at 0x7f4f47278dc0>,
#             <Reaction CO2tex at 0x7f4f47201bb0>,
#             <Reaction COBALT2tex at 0x7f4f4726ed60>,
#             <Reaction CRNDtex at 0x7f4f47221ac0>,
#             <Reaction CRNtex at 0x7f4f471c5700>,
#             <Reaction CSNtex at 0x7f4f471cdfd0>,
#             <Reaction CU2tex at 0x7f4f471f8df0>,
#             <Reaction CUtex at 0x7f4f471cda30>,
#             <Reaction CYANtex at 0x7f4f47187c10>,
#             <Reaction CYNTtex at 0x7f4f47187bb0>,
#             <Reaction CYSDtex at 0x7f4f47196ac0>,
#             <Reaction CYStex at 0x7f4f471a6d90>,
#             <Reaction CYTDtex at 0x7f4f47145f10>,
#             <Reaction DALAtex at 0x7f4f471cde80>,
#             <Reaction DAMPtex at 0x7f4f471d8bb0>,
#             <Reaction DAPtex at 0x7f4f471d8880>,
#             <Reaction DARBtex at 0x7f4f4644bc70>,
#             <Reaction DCAtex at 0x7f4f47187d30>,
#             <Reaction DCMPtex at 0x7f4f47187be0>,
#             <Reaction DDGLCNtex at 0x7f4f47196fa0>,
#             <Reaction DGMPtex at 0x7f4f471a6a90>,
#             <Reaction DGSNtex at 0x7f4f471b4ee0>,
#             <Reaction DHAtex at 0x7f4f47145670>,
#             <Reaction DIMPtex at 0x7f4f47168fd0>,
#             <Reaction DINStex at 0x7f4f47168e20>,
#             <Reaction DMSOtex at 0x7f4f47122be0>,
#             <Reaction DMStex at 0x7f4f47122d30>,
#             <Reaction DOPAtex at 0x7f4f47135d00>,
#             <Reaction DOXRBCNtex at 0x7f4f47135ee0>,
#             <Reaction DSERtex at 0x7f4f470ddc70>,
#             <Reaction DTMPtex at 0x7f4f470c8fd0>,
#             <Reaction DUMPtex at 0x7f4f470f1eb0>,
#             <Reaction D_LACtex at 0x7f4f471568b0>,
#             <Reaction ETHAtex at 0x7f4f470abee0>,
#             <Reaction ETHSO3tex at 0x7f4f47098910>,
#             <Reaction ETOHtex at 0x7f4f470f16a0>,
#             <Reaction F6Ptex at 0x7f4f47052f40>,
#             <Reaction FALDtex at 0x7f4f47076b80>,
#             <Reaction FE2tex at 0x7f4f46fd5e80>,
#             <Reaction FE3tex at 0x7f4f46f901f0>,
#             <Reaction FORtex at 0x7f4f46f90ee0>,
#             <Reaction FRULYStex at 0x7f4f46fa2be0>,
#             <Reaction FRUURtex at 0x7f4f46fb5c10>,
#             <Reaction FRUtex at 0x7f4f46fb54c0>,
#             <Reaction FUCtex at 0x7f4f46f49f70>,
#             <Reaction FUMtex at 0x7f4f46f59fa0>,
#             <Reaction FUSAtex at 0x7f4f46f49cd0>,
#             <Reaction G1Ptex at 0x7f4f46f594f0>,
#             <Reaction G3PCtex at 0x7f4f46f03fd0>,
#             <Reaction G3PEtex at 0x7f4f46f03eb0>,
#             <Reaction G3PGtex at 0x7f4f46f16d90>,
#             <Reaction G3PItex at 0x7f4f46f16c10>,
#             <Reaction G3PStex at 0x7f4f46f03c40>,
#             <Reaction G6Ptex at 0x7f4f46f39fa0>,
#             <Reaction GAL1Ptex at 0x7f4f46f39ac0>,
#             <Reaction GALAMtex at 0x7f4f46552fd0>,
#             <Reaction GALBDtex at 0x7f4f46f28f10>,
#             <Reaction GALCTNLtex at 0x7f4f46ecdb20>,
#             <Reaction GALCTNtex at 0x7f4f46ee1af0>,
#             <Reaction GALCTtex at 0x7f4f46ecda60>,
#             <Reaction GALTtex at 0x7f4f46ef50a0>,
#             <Reaction GALURtex at 0x7f4f46ef5d90>,
#             <Reaction GALtex at 0x7f4f46e9af10>,
#             <Reaction GAMAN6Ptex at 0x7f4f46e9abe0>,
#             <Reaction GAMtex at 0x7f4f46e9a7f0>,
#             <Reaction GBBTNtex at 0x7f4f46ebf8e0>,
#             <Reaction GDPtex at 0x7f4f46e55820>,
#             <Reaction GLCNtex at 0x7f4f46f39c70>,
#             <Reaction GLCRtex at 0x7f4f46ecdc40>,
#             <Reaction GLCUR1Ptex at 0x7f4f46ee1d00>,
#             <Reaction GLCURtex at 0x7f4f46ee1b80>,
#             <Reaction GLCtex_copy1 at 0x7f4f46ef52e0>,
#             <Reaction GLNtex at 0x7f4f46e889a0>,
#             <Reaction GLUtex at 0x7f4f46e55d00>,
#             <Reaction GLYALDtex at 0x7f4f46e69e50>,
#             <Reaction GLYBtex at 0x7f4f46ebfcd0>,
#             <Reaction GLYC2Ptex at 0x7f4f46e7d970>,
#             <Reaction GLYC3Ptex at 0x7f4f46e7df70>,
#             <Reaction GLYCAtex at 0x7f4f46e9acd0>,
#             <Reaction GLYCLTtex at 0x7f4f46e37eb0>,
#             <Reaction GLYCtex at 0x7f4f46daa4c0>,
#             <Reaction GLYtex at 0x7f4f46cde940>,
#             <Reaction GMPtex at 0x7f4f46c7afa0>,
#             <Reaction GSNtex at 0x7f4f46acfeb0>,
#             <Reaction GTHOXtex at 0x7f4f46a856a0>,
#             <Reaction GTHRDtex at 0x7f4f46a03f10>,
#             <Reaction GTPtex at 0x7f4f469edd90>,
#             <Reaction H2O2tex at 0x7f4f46e7dfd0>,
#             <Reaction H2Otex at 0x7f4f46e7de50>,
#             <Reaction H2Stex at 0x7f4f46e215e0>,
#             <Reaction H2tex at 0x7f4f46e21e80>,
#             <Reaction HCINNMtex at 0x7f4f46dda7f0>,
#             <Reaction HG2tex at 0x7f4f46d829a0>,
#             <Reaction HIStex at 0x7f4f46dbdf10>,
#             <Reaction HOMtex at 0x7f4f46d53d30>,
#             <Reaction HPPPNtex at 0x7f4f46d66580>,
#             <Reaction HXAtex at 0x7f4f46e21be0>,
#             <Reaction HYXNtex at 0x7f4f46e10be0>,
#             <Reaction Htex at 0x7f4f46e21b50>,
#             <Reaction IDONtex at 0x7f4f46d829d0>,
#             <Reaction ILEtex at 0x7f4f46d97d90>,
#             <Reaction IMPtex at 0x7f4f46daaf70>,
#             <Reaction INDOLEtex at 0x7f4f46d97ee0>,
#             <Reaction INSTtex at 0x7f4f46d53eb0>,
#             <Reaction ISETACtex at 0x7f4f46d79ee0>,
#             <Reaction Ktex at 0x7f4f46d0fe80>,
#             <Reaction LALADGLUtex at 0x7f4f46cca9a0>,
#             <Reaction LALALGLUtex at 0x7f4f46cdee50>,
#             <Reaction LCTStex at 0x7f4f46cefd00>,
#             <Reaction LEUtex at 0x7f4f46c97a60>,
#             <Reaction LIPOtex at 0x7f4f46c82f10>,
#             <Reaction LYStex at 0x7f4f46c67ee0>,
#             <Reaction LYXtex at 0x7f4f46c54eb0>,
#             <Reaction L_LACtex_copy1 at 0x7f4f46d21f40>,
#             <Reaction L_LACtex_copy2 at 0x7f4f46581d30>,
#             <Reaction MALDtex at 0x7f4f46c7aca0>,
#             <Reaction MALtex at 0x7f4f46c23640>,
#             <Reaction MAN6Ptex at 0x7f4f46c39e80>,
#             <Reaction MANGLYCtex at 0x7f4f46c7ad00>,
#             <Reaction MANtex at 0x7f4f46c10f10>,
#             <Reaction MELIBtex at 0x7f4f46bf0f40>,
#             <Reaction MEOHtex at 0x7f4f46bf0d60>,
#             <Reaction METDtex at 0x7f4f46b85e20>,
#             <Reaction METSOX1tex at 0x7f4f46b85eb0>,
#             <Reaction METSOX2tex at 0x7f4f46b85ee0>,
#             <Reaction METtex at 0x7f4f46bb0f40>,
#             <Reaction MG2tex at 0x7f4f46b9c490>,
#             <Reaction MINCYCtex at 0x7f4f46bde9a0>,
#             <Reaction MMETtex at 0x7f4f46bb0f10>,
#             <Reaction MNLtex at 0x7f4f46b44dc0>,
#             <Reaction MNtex at 0x7f4f46b44f70>,
#             <Reaction MOBDtex at 0x7f4f46bb0f70>,
#             <Reaction MSO3tex at 0x7f4f46b29d30>,
#             <Reaction N2Otex at 0x7f4f46b29d60>,
#             <Reaction NACtex at 0x7f4f46b6cf10>,
#             <Reaction NAtex at 0x7f4f46acff40>,
#             <Reaction NH4tex at 0x7f4f46ae2d30>,
#             <Reaction NI2tex at 0x7f4f46af2ca0>,
#             <Reaction NMNtex at 0x7f4f46a85fa0>,
#             <Reaction NO2tex at 0x7f4f46a42a00>,
#             <Reaction NO3tex at 0x7f4f46acfdf0>,
#             <Reaction NOtex at 0x7f4f46af2e20>,
#             <Reaction O2Stex at 0x7f4f469d7d60>,
#             <Reaction O2tex at 0x7f4f469ede50>,
#             <Reaction OCTAtex at 0x7f4f46a6bc40>,
#             <Reaction ORNtex at 0x7f4f469d7c70>,
#             <Reaction OROTtex at 0x7f4f469edeb0>,
#             <Reaction PACALDtex at 0x7f4f469ffbb0>,
#             <Reaction PACt1 at 0x7f4f4657ff10>,
#             <Reaction PEAMNtex at 0x7f4f469ffe80>,
#             <Reaction PENGt1 at 0x7f4f4657fc10>,
#             <Reaction PHEtex at 0x7f4f468f3a00>,
#             <Reaction PItex at 0x7f4f4688ae80>,
#             <Reaction PNTOtex at 0x7f4f465bf8b0>,
#             <Reaction PPALtex at 0x7f4f46568c70>,
#             <Reaction PPAtex at 0x7f4f4657f280>,
#             <Reaction PPPNtex at 0x7f4f464d2f70>,
#             <Reaction PPTtex at 0x7f4f464e6fa0>,
#             <Reaction PROGLYtex at 0x7f4f469187c0>,
#             <Reaction PROtex at 0x7f4f468f3df0>,
#             <Reaction PSCLYStex at 0x7f4f468f3f10>,
#             <Reaction PSERtex at 0x7f4f4688a7f0>,
#             <Reaction PTRCtex at 0x7f4f46860d90>,
#             <Reaction PYDAMtex at 0x7f4f46830bb0>,
#             <Reaction PYDXNtex at 0x7f4f4681ba30>,
#             <Reaction PYDXtex at 0x7f4f46830c40>,
#             <Reaction PYRtex at 0x7f4f468b5dc0>,
#             <Reaction QUIN2tex at 0x7f4f468b5850>,
#             <Reaction R5Ptex at 0x7f4f46860d30>,
#             <Reaction RAFFtex at 0x7f4f46568eb0>,
#             <Reaction RIBtex at 0x7f4f46808fa0>,
#             <Reaction RMNtex at 0x7f4f46872b50>,
#             <Reaction SALCNtex at 0x7f4f46552f40>,
#             <Reaction SBTtex at 0x7f4f467a77c0>,
#             <Reaction SELtex at 0x7f4f467bdf10>,
#             <Reaction SERtex at 0x7f4f467bd6d0>,
#             <Reaction SKMtex at 0x7f4f46724ca0>,
#             <Reaction SLNTtex at 0x7f4f46724e50>,
#             <Reaction SO2tex at 0x7f4f46737fa0>,
#             <Reaction SO3tex at 0x7f4f46737df0>,
#             <Reaction SO4tex at 0x7f4f466ccf40>,
#             <Reaction SPMDtex at 0x7f4f467ead60>,
#             <Reaction SUCCtex at 0x7f4f467a7e20>,
#             <Reaction SUCRtex at 0x7f4f467bdfd0>,
#             <Reaction SULFACtex at 0x7f4f4674ec70>,
#             <Reaction TARTRDtex at 0x7f4f46765fd0>,
#             <Reaction TARTRtex at 0x7f4f46765c70>,
#             <Reaction TAURtex at 0x7f4f4674ed30>,
#             <Reaction TCYNTtex at 0x7f4f4670dee0>,
#             <Reaction THMDtex at 0x7f4f46737b50>,
#             <Reaction THMtex at 0x7f4f466cce20>,
#             <Reaction THRPtex at 0x7f4f466debe0>,
#             <Reaction THRtex at 0x7f4f46688bb0>,
#             <Reaction THYMtex at 0x7f4f466def70>,
#             <Reaction TMAOtex at 0x7f4f4669e3d0>,
#             <Reaction TMAtex at 0x7f4f4669eeb0>,
#             <Reaction TREtex at 0x7f4f46670d90>,
#             <Reaction TRPtex at 0x7f4f46604a90>,
#             <Reaction TSULtex at 0x7f4f46619d00>,
#             <Reaction TTRCYCtex at 0x7f4f46619f40>,
#             <Reaction TUNGStex at 0x7f4f4662ec40>,
#             <Reaction TYMtex at 0x7f4f4662ec70>,
#             <Reaction TYRPtex at 0x7f4f465d7d00>,
#             <Reaction TYRtex at 0x7f4f466e78e0>,
#             <Reaction UACGAMtex at 0x7f4f46688e20>,
#             <Reaction UDPACGALtex at 0x7f4f466b2a90>,
#             <Reaction UDPGALtex at 0x7f4f46658d90>,
#             <Reaction UDPGLCURtex at 0x7f4f46658fa0>,
#             <Reaction UDPGtex at 0x7f4f46670c70>,
#             <Reaction UMPtex at 0x7f4f4662efa0>,
#             <Reaction URAtex at 0x7f4f465c17c0>,
#             <Reaction UREAtex at 0x7f4f465d7940>,
#             <Reaction VALtex at 0x7f4f46619e80>,
#             <Reaction XANtex at 0x7f4f465d7fa0>,
#             <Reaction XMPtex at 0x7f4f46581be0>,
#             <Reaction XTSNtex at 0x7f4f46581fd0>,
#             <Reaction XYLUtex at 0x7f4f46581940>,
#             <Reaction XYLtex at 0x7f4f465a9d00>,
#             <Reaction Zn2tex at 0x7f4f465a9d90>}),
#  'OmpF': frozenset({<Reaction 12PPDRtex at 0x7f4f47451790>,
#             <Reaction 12PPDStex at 0x7f4f47451820>,
#             <Reaction 23CAMPtex at 0x7f4f47451be0>,
#             <Reaction 23CCMPtex at 0x7f4f47451f70>,
#             <Reaction 23CGMPtex at 0x7f4f47451fa0>,
#             <Reaction 23CUMPtex at 0x7f4f474518e0>,
#             <Reaction 23DAPPAtex at 0x7f4f47451e50>,
#             <Reaction 26DAHtex at 0x7f4f47460bb0>,
#             <Reaction 34dhpactex at 0x7f4f47427940>,
#             <Reaction 3AMPtex at 0x7f4f47427f40>,
#             <Reaction 3CMPtex at 0x7f4f47427a00>,
#             <Reaction 3GMPtex at 0x7f4f47419f70>,
#             <Reaction 3HPPtex at 0x7f4f473c5df0>,
#             <Reaction 3PEPTtex at 0x7f4f47388d30>,
#             <Reaction 3UMPtex at 0x7f4f473936d0>,
#             <Reaction 3hoxpactex at 0x7f4f46568c40>,
#             <Reaction 4HOXPACDtex at 0x7f4f47393f40>,
#             <Reaction 4PEPTtex at 0x7f4f473b0f70>,
#             <Reaction 4hoxpactex at 0x7f4f46568dc0>,
#             <Reaction 5DGLCNtex at 0x7f4f473bd940>,
#             <Reaction 5MTRtex at 0x7f4f473bd610>,
#             <Reaction 6APAt1 at 0x7f4f46514be0>,
#             <Reaction ABUTtex at 0x7f4f473c5ee0>,
#             <Reaction ACACtex at 0x7f4f473dffa0>,
#             <Reaction ACALDtex at 0x7f4f473fad60>,
#             <Reaction ACGAL1Ptex at 0x7f4f473ee970>,
#             <Reaction ACGALtex at 0x7f4f47388bb0>,
#             <Reaction ACGAM1Ptex at 0x7f4f47388e80>,
#             <Reaction ACGAtex at 0x7f4f47393bb0>,
#             <Reaction ACMANAtex at 0x7f4f473939a0>,
#             <Reaction ACMUMtex at 0x7f4f473bdb50>,
#             <Reaction ACNAMtex at 0x7f4f473b06a0>,
#             <Reaction ACSERtex at 0x7f4f47379ee0>,
#             <Reaction ACtex at 0x7f4f473098e0>,
#             <Reaction ADEtex at 0x7f4f47318e50>,
#             <Reaction AGMtex at 0x7f4f4ef91a90>,
#             <Reaction AKGtex at 0x7f4f4736b8e0>,
#             <Reaction ALAALAtex at 0x7f4f4736b820>,
#             <Reaction ALAtex at 0x7f4f47327cd0>,
#             <Reaction ALLTNtex at 0x7f4f4ef6fc40>,
#             <Reaction ALLtex at 0x7f4f4ef79160>,
#             <Reaction AMPtex at 0x7f4f4ec03610>,
#             <Reaction ANHGMtex at 0x7f4f4ef95af0>,
#             <Reaction ARBTtex at 0x7f4f471b4fa0>,
#             <Reaction ARBtex at 0x7f4f4710d910>,
#             <Reaction ARGtex at 0x7f4f470f1f40>,
#             <Reaction ASCBtex at 0x7f4f4700af70>,
#             <Reaction ASNtex at 0x7f4f46fb5a90>,
#             <Reaction ASO3tex at 0x7f4f46f59f10>,
#             <Reaction ASPtex at 0x7f4f4c1861c0>,
#             <Reaction BALAtex at 0x7f4f4c0ebd90>,
#             <Reaction BTNtex at 0x7f4f4c122df0>,
#             <Reaction BUTSO3tex at 0x7f4f4c0c3be0>,
#             <Reaction BUTtex at 0x7f4f472c7d30>,
#             <Reaction CA2tex at 0x7f4f47240e80>,
#             <Reaction CD2tex at 0x7f4f47260ac0>,
#             <Reaction CGLYtex at 0x7f4f4c115c40>,
#             <Reaction CHLtex at 0x7f4f4c115220>,
#             <Reaction CHTBStex at 0x7f4f4752cbe0>,
#             <Reaction CITtex at 0x7f4f4c0b8eb0>,
#             <Reaction CLBtex at 0x7f4f465bfa90>,
#             <Reaction CLtex at 0x7f4f472589a0>,
#             <Reaction CMPtex at 0x7f4f472b98e0>,
#             <Reaction CMtex at 0x7f4f47278dc0>,
#             <Reaction CO2tex at 0x7f4f47201bb0>,
#             <Reaction COBALT2tex at 0x7f4f4726ed60>,
#             <Reaction CRNDtex at 0x7f4f47221ac0>,
#             <Reaction CRNtex at 0x7f4f471c5700>,
#             <Reaction CSNtex at 0x7f4f471cdfd0>,
#             <Reaction CU2tex at 0x7f4f471f8df0>,
#             <Reaction CUtex at 0x7f4f471cda30>,
#             <Reaction CYANtex at 0x7f4f47187c10>,
#             <Reaction CYNTtex at 0x7f4f47187bb0>,
#             <Reaction CYSDtex at 0x7f4f47196ac0>,
#             <Reaction CYStex at 0x7f4f471a6d90>,
#             <Reaction CYTDtex at 0x7f4f47145f10>,
#             <Reaction DALAtex at 0x7f4f471cde80>,
#             <Reaction DAMPtex at 0x7f4f471d8bb0>,
#             <Reaction DAPtex at 0x7f4f471d8880>,
#             <Reaction DARBtex at 0x7f4f4644bc70>,
#             <Reaction DCAtex at 0x7f4f47187d30>,
#             <Reaction DCMPtex at 0x7f4f47187be0>,
#             <Reaction DDGLCNtex at 0x7f4f47196fa0>,
#             <Reaction DGMPtex at 0x7f4f471a6a90>,
#             <Reaction DGSNtex at 0x7f4f471b4ee0>,
#             <Reaction DHAtex at 0x7f4f47145670>,
#             <Reaction DIMPtex at 0x7f4f47168fd0>,
#             <Reaction DINStex at 0x7f4f47168e20>,
#             <Reaction DMSOtex at 0x7f4f47122be0>,
#             <Reaction DMStex at 0x7f4f47122d30>,
#             <Reaction DOPAtex at 0x7f4f47135d00>,
#             <Reaction DOXRBCNtex at 0x7f4f47135ee0>,
#             <Reaction DSERtex at 0x7f4f470ddc70>,
#             <Reaction DTMPtex at 0x7f4f470c8fd0>,
#             <Reaction DUMPtex at 0x7f4f470f1eb0>,
#             <Reaction D_LACtex at 0x7f4f471568b0>,
#             <Reaction ETHAtex at 0x7f4f470abee0>,
#             <Reaction ETHSO3tex at 0x7f4f47098910>,
#             <Reaction ETOHtex at 0x7f4f470f16a0>,
#             <Reaction F6Ptex at 0x7f4f47052f40>,
#             <Reaction FALDtex at 0x7f4f47076b80>,
#             <Reaction FE2tex at 0x7f4f46fd5e80>,
#             <Reaction FE3tex at 0x7f4f46f901f0>,
#             <Reaction FORtex at 0x7f4f46f90ee0>,
#             <Reaction FRULYStex at 0x7f4f46fa2be0>,
#             <Reaction FRUURtex at 0x7f4f46fb5c10>,
#             <Reaction FRUtex at 0x7f4f46fb54c0>,
#             <Reaction FUCtex at 0x7f4f46f49f70>,
#             <Reaction FUMtex at 0x7f4f46f59fa0>,
#             <Reaction FUSAtex at 0x7f4f46f49cd0>,
#             <Reaction G1Ptex at 0x7f4f46f594f0>,
#             <Reaction G3PCtex at 0x7f4f46f03fd0>,
#             <Reaction G3PEtex at 0x7f4f46f03eb0>,
#             <Reaction G3PGtex at 0x7f4f46f16d90>,
#             <Reaction G3PItex at 0x7f4f46f16c10>,
#             <Reaction G3PStex at 0x7f4f46f03c40>,
#             <Reaction G6Ptex at 0x7f4f46f39fa0>,
#             <Reaction GAL1Ptex at 0x7f4f46f39ac0>,
#             <Reaction GALAMtex at 0x7f4f46552fd0>,
#             <Reaction GALBDtex at 0x7f4f46f28f10>,
#             <Reaction GALCTNLtex at 0x7f4f46ecdb20>,
#             <Reaction GALCTNtex at 0x7f4f46ee1af0>,
#             <Reaction GALCTtex at 0x7f4f46ecda60>,
#             <Reaction GALTtex at 0x7f4f46ef50a0>,
#             <Reaction GALURtex at 0x7f4f46ef5d90>,
#             <Reaction GALtex at 0x7f4f46e9af10>,
#             <Reaction GAMAN6Ptex at 0x7f4f46e9abe0>,
#             <Reaction GAMtex at 0x7f4f46e9a7f0>,
#             <Reaction GBBTNtex at 0x7f4f46ebf8e0>,
#             <Reaction GDPtex at 0x7f4f46e55820>,
#             <Reaction GLCNtex at 0x7f4f46f39c70>,
#             <Reaction GLCRtex at 0x7f4f46ecdc40>,
#             <Reaction GLCUR1Ptex at 0x7f4f46ee1d00>,
#             <Reaction GLCURtex at 0x7f4f46ee1b80>,
#             <Reaction GLCtex_copy1 at 0x7f4f46ef52e0>,
#             <Reaction GLNtex at 0x7f4f46e889a0>,
#             <Reaction GLUtex at 0x7f4f46e55d00>,
#             <Reaction GLYALDtex at 0x7f4f46e69e50>,
#             <Reaction GLYBtex at 0x7f4f46ebfcd0>,
#             <Reaction GLYC2Ptex at 0x7f4f46e7d970>,
#             <Reaction GLYC3Ptex at 0x7f4f46e7df70>,
#             <Reaction GLYCAtex at 0x7f4f46e9acd0>,
#             <Reaction GLYCLTtex at 0x7f4f46e37eb0>,
#             <Reaction GLYCtex at 0x7f4f46daa4c0>,
#             <Reaction GLYtex at 0x7f4f46cde940>,
#             <Reaction GMPtex at 0x7f4f46c7afa0>,
#             <Reaction GSNtex at 0x7f4f46acfeb0>,
#             <Reaction GTHOXtex at 0x7f4f46a856a0>,
#             <Reaction GTHRDtex at 0x7f4f46a03f10>,
#             <Reaction GTPtex at 0x7f4f469edd90>,
#             <Reaction H2O2tex at 0x7f4f46e7dfd0>,
#             <Reaction H2Otex at 0x7f4f46e7de50>,
#             <Reaction H2Stex at 0x7f4f46e215e0>,
#             <Reaction H2tex at 0x7f4f46e21e80>,
#             <Reaction HCINNMtex at 0x7f4f46dda7f0>,
#             <Reaction HG2tex at 0x7f4f46d829a0>,
#             <Reaction HIStex at 0x7f4f46dbdf10>,
#             <Reaction HOMtex at 0x7f4f46d53d30>,
#             <Reaction HPPPNtex at 0x7f4f46d66580>,
#             <Reaction HXAtex at 0x7f4f46e21be0>,
#             <Reaction HYXNtex at 0x7f4f46e10be0>,
#             <Reaction Htex at 0x7f4f46e21b50>,
#             <Reaction IDONtex at 0x7f4f46d829d0>,
#             <Reaction ILEtex at 0x7f4f46d97d90>,
#             <Reaction IMPtex at 0x7f4f46daaf70>,
#             <Reaction INDOLEtex at 0x7f4f46d97ee0>,
#             <Reaction INSTtex at 0x7f4f46d53eb0>,
#             <Reaction ISETACtex at 0x7f4f46d79ee0>,
#             <Reaction Ktex at 0x7f4f46d0fe80>,
#             <Reaction LALADGLUtex at 0x7f4f46cca9a0>,
#             <Reaction LALALGLUtex at 0x7f4f46cdee50>,
#             <Reaction LCTStex at 0x7f4f46cefd00>,
#             <Reaction LEUtex at 0x7f4f46c97a60>,
#             <Reaction LIPOtex at 0x7f4f46c82f10>,
#             <Reaction LYStex at 0x7f4f46c67ee0>,
#             <Reaction LYXtex at 0x7f4f46c54eb0>,
#             <Reaction L_LACtex_copy1 at 0x7f4f46d21f40>,
#             <Reaction L_LACtex_copy2 at 0x7f4f46581d30>,
#             <Reaction MALDtex at 0x7f4f46c7aca0>,
#             <Reaction MALtex at 0x7f4f46c23640>,
#             <Reaction MAN6Ptex at 0x7f4f46c39e80>,
#             <Reaction MANGLYCtex at 0x7f4f46c7ad00>,
#             <Reaction MANtex at 0x7f4f46c10f10>,
#             <Reaction MELIBtex at 0x7f4f46bf0f40>,
#             <Reaction MEOHtex at 0x7f4f46bf0d60>,
#             <Reaction METDtex at 0x7f4f46b85e20>,
#             <Reaction METSOX1tex at 0x7f4f46b85eb0>,
#             <Reaction METSOX2tex at 0x7f4f46b85ee0>,
#             <Reaction METtex at 0x7f4f46bb0f40>,
#             <Reaction MG2tex at 0x7f4f46b9c490>,
#             <Reaction MINCYCtex at 0x7f4f46bde9a0>,
#             <Reaction MMETtex at 0x7f4f46bb0f10>,
#             <Reaction MNLtex at 0x7f4f46b44dc0>,
#             <Reaction MNtex at 0x7f4f46b44f70>,
#             <Reaction MOBDtex at 0x7f4f46bb0f70>,
#             <Reaction MSO3tex at 0x7f4f46b29d30>,
#             <Reaction N2Otex at 0x7f4f46b29d60>,
#             <Reaction NACtex at 0x7f4f46b6cf10>,
#             <Reaction NAtex at 0x7f4f46acff40>,
#             <Reaction NH4tex at 0x7f4f46ae2d30>,
#             <Reaction NI2tex at 0x7f4f46af2ca0>,
#             <Reaction NMNtex at 0x7f4f46a85fa0>,
#             <Reaction NO2tex at 0x7f4f46a42a00>,
#             <Reaction NO3tex at 0x7f4f46acfdf0>,
#             <Reaction NOtex at 0x7f4f46af2e20>,
#             <Reaction O2Stex at 0x7f4f469d7d60>,
#             <Reaction O2tex at 0x7f4f469ede50>,
#             <Reaction OCTAtex at 0x7f4f46a6bc40>,
#             <Reaction ORNtex at 0x7f4f469d7c70>,
#             <Reaction OROTtex at 0x7f4f469edeb0>,
#             <Reaction PACALDtex at 0x7f4f469ffbb0>,
#             <Reaction PACt1 at 0x7f4f4657ff10>,
#             <Reaction PEAMNtex at 0x7f4f469ffe80>,
#             <Reaction PENGt1 at 0x7f4f4657fc10>,
#             <Reaction PHEtex at 0x7f4f468f3a00>,
#             <Reaction PItex at 0x7f4f4688ae80>,
#             <Reaction PNTOtex at 0x7f4f465bf8b0>,
#             <Reaction PPALtex at 0x7f4f46568c70>,
#             <Reaction PPAtex at 0x7f4f4657f280>,
#             <Reaction PPPNtex at 0x7f4f464d2f70>,
#             <Reaction PPTtex at 0x7f4f464e6fa0>,
#             <Reaction PROGLYtex at 0x7f4f469187c0>,
#             <Reaction PROtex at 0x7f4f468f3df0>,
#             <Reaction PSCLYStex at 0x7f4f468f3f10>,
#             <Reaction PSERtex at 0x7f4f4688a7f0>,
#             <Reaction PTRCtex at 0x7f4f46860d90>,
#             <Reaction PYDAMtex at 0x7f4f46830bb0>,
#             <Reaction PYDXNtex at 0x7f4f4681ba30>,
#             <Reaction PYDXtex at 0x7f4f46830c40>,
#             <Reaction PYRtex at 0x7f4f468b5dc0>,
#             <Reaction QUIN2tex at 0x7f4f468b5850>,
#             <Reaction R5Ptex at 0x7f4f46860d30>,
#             <Reaction RAFFtex at 0x7f4f46568eb0>,
#             <Reaction RIBtex at 0x7f4f46808fa0>,
#             <Reaction RMNtex at 0x7f4f46872b50>,
#             <Reaction SALCNtex at 0x7f4f46552f40>,
#             <Reaction SBTtex at 0x7f4f467a77c0>,
#             <Reaction SELtex at 0x7f4f467bdf10>,
#             <Reaction SERtex at 0x7f4f467bd6d0>,
#             <Reaction SKMtex at 0x7f4f46724ca0>,
#             <Reaction SLNTtex at 0x7f4f46724e50>,
#             <Reaction SO2tex at 0x7f4f46737fa0>,
#             <Reaction SO3tex at 0x7f4f46737df0>,
#             <Reaction SO4tex at 0x7f4f466ccf40>,
#             <Reaction SPMDtex at 0x7f4f467ead60>,
#             <Reaction SUCCtex at 0x7f4f467a7e20>,
#             <Reaction SUCRtex at 0x7f4f467bdfd0>,
#             <Reaction SULFACtex at 0x7f4f4674ec70>,
#             <Reaction TARTRDtex at 0x7f4f46765fd0>,
#             <Reaction TARTRtex at 0x7f4f46765c70>,
#             <Reaction TAURtex at 0x7f4f4674ed30>,
#             <Reaction TCYNTtex at 0x7f4f4670dee0>,
#             <Reaction THMDtex at 0x7f4f46737b50>,
#             <Reaction THMtex at 0x7f4f466cce20>,
#             <Reaction THRPtex at 0x7f4f466debe0>,
#             <Reaction THRtex at 0x7f4f46688bb0>,
#             <Reaction THYMtex at 0x7f4f466def70>,
#             <Reaction TMAOtex at 0x7f4f4669e3d0>,
#             <Reaction TMAtex at 0x7f4f4669eeb0>,
#             <Reaction TREtex at 0x7f4f46670d90>,
#             <Reaction TRPtex at 0x7f4f46604a90>,
#             <Reaction TSULtex at 0x7f4f46619d00>,
#             <Reaction TTRCYCtex at 0x7f4f46619f40>,
#             <Reaction TUNGStex at 0x7f4f4662ec40>,
#             <Reaction TYMtex at 0x7f4f4662ec70>,
#             <Reaction TYRPtex at 0x7f4f465d7d00>,
#             <Reaction TYRtex at 0x7f4f466e78e0>,
#             <Reaction UACGAMtex at 0x7f4f46688e20>,
#             <Reaction UDPACGALtex at 0x7f4f466b2a90>,
#             <Reaction UDPGALtex at 0x7f4f46658d90>,
#             <Reaction UDPGLCURtex at 0x7f4f46658fa0>,
#             <Reaction UDPGtex at 0x7f4f46670c70>,
#             <Reaction UMPtex at 0x7f4f4662efa0>,
#             <Reaction URAtex at 0x7f4f465c17c0>,
#             <Reaction UREAtex at 0x7f4f465d7940>,
#             <Reaction VALtex at 0x7f4f46619e80>,
#             <Reaction XANtex at 0x7f4f465d7fa0>,
#             <Reaction XMPtex at 0x7f4f46581be0>,
#             <Reaction XTSNtex at 0x7f4f46581fd0>,
#             <Reaction XYLUtex at 0x7f4f46581940>,
#             <Reaction XYLtex at 0x7f4f465a9d00>,
#             <Reaction Zn2tex at 0x7f4f465a9d90>}),
#  'OmpN': frozenset({<Reaction 12PPDRtex at 0x7f4f47451790>,
#             <Reaction 12PPDStex at 0x7f4f47451820>,
#             <Reaction 23CAMPtex at 0x7f4f47451be0>,
#             <Reaction 23CCMPtex at 0x7f4f47451f70>,
#             <Reaction 23CGMPtex at 0x7f4f47451fa0>,
#             <Reaction 23CUMPtex at 0x7f4f474518e0>,
#             <Reaction 23DAPPAtex at 0x7f4f47451e50>,
#             <Reaction 26DAHtex at 0x7f4f47460bb0>,
#             <Reaction 34dhpactex at 0x7f4f47427940>,
#             <Reaction 3AMPtex at 0x7f4f47427f40>,
#             <Reaction 3CMPtex at 0x7f4f47427a00>,
#             <Reaction 3GMPtex at 0x7f4f47419f70>,
#             <Reaction 3HPPtex at 0x7f4f473c5df0>,
#             <Reaction 3PEPTtex at 0x7f4f47388d30>,
#             <Reaction 3UMPtex at 0x7f4f473936d0>,
#             <Reaction 3hoxpactex at 0x7f4f46568c40>,
#             <Reaction 4HOXPACDtex at 0x7f4f47393f40>,
#             <Reaction 4PEPTtex at 0x7f4f473b0f70>,
#             <Reaction 4hoxpactex at 0x7f4f46568dc0>,
#             <Reaction 5DGLCNtex at 0x7f4f473bd940>,
#             <Reaction 5MTRtex at 0x7f4f473bd610>,
#             <Reaction 6APAt1 at 0x7f4f46514be0>,
#             <Reaction ABUTtex at 0x7f4f473c5ee0>,
#             <Reaction ACACtex at 0x7f4f473dffa0>,
#             <Reaction ACALDtex at 0x7f4f473fad60>,
#             <Reaction ACGAL1Ptex at 0x7f4f473ee970>,
#             <Reaction ACGALtex at 0x7f4f47388bb0>,
#             <Reaction ACGAM1Ptex at 0x7f4f47388e80>,
#             <Reaction ACGAtex at 0x7f4f47393bb0>,
#             <Reaction ACMANAtex at 0x7f4f473939a0>,
#             <Reaction ACMUMtex at 0x7f4f473bdb50>,
#             <Reaction ACSERtex at 0x7f4f47379ee0>,
#             <Reaction ACtex at 0x7f4f473098e0>,
#             <Reaction ADEtex at 0x7f4f47318e50>,
#             <Reaction AGMtex at 0x7f4f4ef91a90>,
#             <Reaction AKGtex at 0x7f4f4736b8e0>,
#             <Reaction ALAALAtex at 0x7f4f4736b820>,
#             <Reaction ALAtex at 0x7f4f47327cd0>,
#             <Reaction ALLTNtex at 0x7f4f4ef6fc40>,
#             <Reaction ALLtex at 0x7f4f4ef79160>,
#             <Reaction AMPtex at 0x7f4f4ec03610>,
#             <Reaction ANHGMtex at 0x7f4f4ef95af0>,
#             <Reaction ARBTtex at 0x7f4f471b4fa0>,
#             <Reaction ARBtex at 0x7f4f4710d910>,
#             <Reaction ARGtex at 0x7f4f470f1f40>,
#             <Reaction ASCBtex at 0x7f4f4700af70>,
#             <Reaction ASNtex at 0x7f4f46fb5a90>,
#             <Reaction ASO3tex at 0x7f4f46f59f10>,
#             <Reaction ASPtex at 0x7f4f4c1861c0>,
#             <Reaction BALAtex at 0x7f4f4c0ebd90>,
#             <Reaction BTNtex at 0x7f4f4c122df0>,
#             <Reaction BUTSO3tex at 0x7f4f4c0c3be0>,
#             <Reaction BUTtex at 0x7f4f472c7d30>,
#             <Reaction CA2tex at 0x7f4f47240e80>,
#             <Reaction CD2tex at 0x7f4f47260ac0>,
#             <Reaction CGLYtex at 0x7f4f4c115c40>,
#             <Reaction CHLtex at 0x7f4f4c115220>,
#             <Reaction CHTBStex at 0x7f4f4752cbe0>,
#             <Reaction CITtex at 0x7f4f4c0b8eb0>,
#             <Reaction CLBtex at 0x7f4f465bfa90>,
#             <Reaction CLtex at 0x7f4f472589a0>,
#             <Reaction CMPtex at 0x7f4f472b98e0>,
#             <Reaction CMtex at 0x7f4f47278dc0>,
#             <Reaction CO2tex at 0x7f4f47201bb0>,
#             <Reaction COBALT2tex at 0x7f4f4726ed60>,
#             <Reaction CRNDtex at 0x7f4f47221ac0>,
#             <Reaction CRNtex at 0x7f4f471c5700>,
#             <Reaction CSNtex at 0x7f4f471cdfd0>,
#             <Reaction CU2tex at 0x7f4f471f8df0>,
#             <Reaction CUtex at 0x7f4f471cda30>,
#             <Reaction CYANtex at 0x7f4f47187c10>,
#             <Reaction CYNTtex at 0x7f4f47187bb0>,
#             <Reaction CYSDtex at 0x7f4f47196ac0>,
#             <Reaction CYStex at 0x7f4f471a6d90>,
#             <Reaction CYTDtex at 0x7f4f47145f10>,
#             <Reaction DALAtex at 0x7f4f471cde80>,
#             <Reaction DAMPtex at 0x7f4f471d8bb0>,
#             <Reaction DAPtex at 0x7f4f471d8880>,
#             <Reaction DARBtex at 0x7f4f4644bc70>,
#             <Reaction DCAtex at 0x7f4f47187d30>,
#             <Reaction DCMPtex at 0x7f4f47187be0>,
#             <Reaction DDGLCNtex at 0x7f4f47196fa0>,
#             <Reaction DGMPtex at 0x7f4f471a6a90>,
#             <Reaction DGSNtex at 0x7f4f471b4ee0>,
#             <Reaction DHAtex at 0x7f4f47145670>,
#             <Reaction DIMPtex at 0x7f4f47168fd0>,
#             <Reaction DINStex at 0x7f4f47168e20>,
#             <Reaction DMSOtex at 0x7f4f47122be0>,
#             <Reaction DMStex at 0x7f4f47122d30>,
#             <Reaction DOPAtex at 0x7f4f47135d00>,
#             <Reaction DOXRBCNtex at 0x7f4f47135ee0>,
#             <Reaction DSERtex at 0x7f4f470ddc70>,
#             <Reaction DTMPtex at 0x7f4f470c8fd0>,
#             <Reaction DUMPtex at 0x7f4f470f1eb0>,
#             <Reaction D_LACtex at 0x7f4f471568b0>,
#             <Reaction ETHAtex at 0x7f4f470abee0>,
#             <Reaction ETHSO3tex at 0x7f4f47098910>,
#             <Reaction ETOHtex at 0x7f4f470f16a0>,
#             <Reaction F6Ptex at 0x7f4f47052f40>,
#             <Reaction FALDtex at 0x7f4f47076b80>,
#             <Reaction FE2tex at 0x7f4f46fd5e80>,
#             <Reaction FE3tex at 0x7f4f46f901f0>,
#             <Reaction FORtex at 0x7f4f46f90ee0>,
#             <Reaction FRULYStex at 0x7f4f46fa2be0>,
#             <Reaction FRUURtex at 0x7f4f46fb5c10>,
#             <Reaction FRUtex at 0x7f4f46fb54c0>,
#             <Reaction FUCtex at 0x7f4f46f49f70>,
#             <Reaction FUMtex at 0x7f4f46f59fa0>,
#             <Reaction FUSAtex at 0x7f4f46f49cd0>,
# ...
#  'OmpG': frozenset({<Reaction H2Otex at 0x7f4f46e7de50>}),
#  'Pgm': frozenset({<Reaction PGMT at 0x7f4f4696cc10>}),
#  'OmpA': frozenset({<Reaction H2Otex at 0x7f4f46e7de50>}),
#  'MaeA': frozenset({<Reaction ME1 at 0x7f4f46bdebb0>}),
#  'PgpA': frozenset({<Reaction PGPP120 at 0x7f4f46918fa0>,
#             <Reaction PGPP120pp at 0x7f4f46903f10>,
#             <Reaction PGPP140 at 0x7f4f46903e80>,
#             <Reaction PGPP140pp at 0x7f4f469a8d60>,
#             <Reaction PGPP141 at 0x7f4f46918d30>,
#             <Reaction PGPP141pp at 0x7f4f46903d60>,
#             <Reaction PGPP160 at 0x7f4f469188e0>,
#             <Reaction PGPP160pp at 0x7f4f46918af0>,
#             <Reaction PGPP161 at 0x7f4f46918f70>,
#             <Reaction PGPP161pp at 0x7f4f46930f40>,
#             <Reaction PGPP180 at 0x7f4f46930d00>,
#             <Reaction PGPP180pp at 0x7f4f46918dc0>,
#             <Reaction PGPP181 at 0x7f4f46930dc0>,
#             <Reaction PGPP181pp at 0x7f4f46930e50>}),
#  'MaeB': frozenset({<Reaction ME2 at 0x7f4f46bcdf10>}),
#  'PgsA': frozenset({<Reaction PGSA120 at 0x7f4f468c8f70>,
#             <Reaction PGSA140 at 0x7f4f468c8fa0>,
#             <Reaction PGSA141 at 0x7f4f468c8fd0>,
#             <Reaction PGSA160 at 0x7f4f468c8ee0>,
#             <Reaction PGSA161 at 0x7f4f468c8b20>,
#             <Reaction PGSA180 at 0x7f4f468ddd30>,
#             <Reaction PGSA181 at 0x7f4f468ddaf0>}),
#  'IspG': frozenset({<Reaction MECDPDH2 at 0x7f4f46595790>,
#             <Reaction MECDPDH5 at 0x7f4f46bdee50>}),
#  'AqpZ': frozenset({<Reaction H2Otpp at 0x7f4f46e10c40>}),
#  'CcmB': frozenset({<Reaction PHEMEabcpp at 0x7f4f468dd700>}),
#  'UbiA': frozenset({<Reaction HBZOPT at 0x7f4f46dcaeb0>}),
#  'CcmE': frozenset({<Reaction PHEMEabcpp at 0x7f4f468dd700>}),
#  'MhpT': frozenset({<Reaction HCINNMt2rpp at 0x7f4f46dcae50>,
#             <Reaction HPPPNt2rpp at 0x7f4f46d53fd0>}),
#  'CynT': frozenset({<Reaction HCO3E at 0x7f4f46ddaee0>}),
#  'IspF': frozenset({<Reaction MECDPS at 0x7f4f46bde940>}),
#  'MelB': frozenset({<Reaction MELIBt2pp at 0x7f4f46bdec70>}),
#  'CcmC': frozenset({<Reaction PHEMEabcpp at 0x7f4f468dd700>}),
#  'IspD': frozenset({<Reaction MEPCT at 0x7f4f46b85dc0>}),
#  'Can': frozenset({<Reaction HCO3E at 0x7f4f46ddaee0>}),
#  'CcmD': frozenset({<Reaction PHEMEabcpp at 0x7f4f468dd700>}),
#  'CyoE': frozenset({<Reaction HEMEOS at 0x7f4f46defeb0>}),
#  'MetK': frozenset({<Reaction METAT at 0x7f4f46b859d0>}),
#  'CcmA': frozenset({<Reaction PHEMEabcpp at 0x7f4f468dd700>}),
#  'MetN': frozenset({<Reaction METDabcpp at 0x7f4f46b858e0>,
#             <Reaction METabcpp at 0x7f4f46b9cc70>}),
#  'PheS': frozenset({<Reaction PHETRS at 0x7f4f468f3eb0>}),
#  'MetI': frozenset({<Reaction METDabcpp at 0x7f4f46b858e0>,
#             <Reaction METabcpp at 0x7f4f46b9cc70>}),
#  'RfaP': frozenset({<Reaction HEPK1 at 0x7f4f46defb80>,
#             <Reaction HEPKA1 at 0x7f4f464f9fd0>,
#             <Reaction HEPKB1 at 0x7f4f4648baf0>}),
#  'PheT': frozenset({<Reaction PHETRS at 0x7f4f468f3eb0>}),
#  'PheP': frozenset({<Reaction PHEt2rpp at 0x7f4f468f3ee0>,
#             <Reaction TYRt2rpp at 0x7f4f466e7f40>}),
#  'RfaY': frozenset({<Reaction HEPK2 at 0x7f4f46dcac10>,
#             <Reaction HEPKA2 at 0x7f4f464f9d00>,
#             <Reaction HEPKB2 at 0x7f4f4648be20>}),
#  'RfaC': frozenset({<Reaction HEPT1 at 0x7f4f46defee0>,
#             <Reaction HEPTA1 at 0x7f4f464e6940>,
#             <Reaction HEPTB1 at 0x7f4f4648bb50>}),
#  'MetQ': frozenset({<Reaction METDabcpp at 0x7f4f46b858e0>,
#             <Reaction METabcpp at 0x7f4f46b9cc70>}),
#  'MetE': frozenset({<Reaction METS at 0x7f4f46b9ccd0>}),
#  'YddG': frozenset({<Reaction PHEt2rpp at 0x7f4f468f3ee0>,
#             <Reaction TRPt2rpp at 0x7f4f46604d30>,
#             <Reaction TYRt2rpp at 0x7f4f466e7f40>}),
#  'RfaF': frozenset({<Reaction HEPT2 at 0x7f4f46def610>,
#             <Reaction HEPTA2 at 0x7f4f464f9e20>,
#             <Reaction HEPTB2 at 0x7f4f4648bd00>}),
#  'PitA': frozenset({<Reaction PIt2rpp at 0x7f4f468f3ca0>}),
#  'RfaQ': frozenset({<Reaction HEPT3 at 0x7f4f46d82d30>,
#             <Reaction HEPTA3 at 0x7f4f464f9040>,
#             <Reaction HEPTB3 at 0x7f4f464f9a90>}),
#  'MetH': frozenset({<Reaction METS at 0x7f4f46b9ccd0>}),
#  'PitB': frozenset({<Reaction PIt2rpp at 0x7f4f468f3ca0>}),
#  'MsrA': frozenset({<Reaction METSOXR1 at 0x7f4f46bb0970>}),
#  'MsrB': frozenset({<Reaction METSOXR2 at 0x7f4f46b9ce50>}),
#  'ThiM': frozenset({<Reaction HETZK at 0x7f4f46deff10>}),
#  'PstA': frozenset({<Reaction PIuabcpp at 0x7f4f468f3040>}),
#  'MetG': frozenset({<Reaction METTRS at 0x7f4f46bb0670>}),
#  'PstB': frozenset({<Reaction PIuabcpp at 0x7f4f468f3040>}),
#  'MgtA': frozenset({<Reaction MG2uabcpp at 0x7f4f46b44bb0>,
#             <Reaction NI2uabcpp at 0x7f4f46a9afa0>}),
#  'MgsA': frozenset({<Reaction MGSA at 0x7f4f46b58d90>}),
#  'PstS': frozenset({<Reaction PIuabcpp at 0x7f4f468f3040>}),
#  'MalZ': frozenset({<Reaction MLTG1 at 0x7f4f46bf0f10>,
#             <Reaction MLTG2 at 0x7f4f46bf0580>,
#             <Reaction MLTG3 at 0x7f4f46d97cd0>,
#             <Reaction MLTG4 at 0x7f4f46bf0fd0>,
#             <Reaction MLTG5 at 0x7f4f46bf09a0>}),
#  'PstC': frozenset({<Reaction PIuabcpp at 0x7f4f468f3040>}),
#  'Glk': frozenset({<Reaction HEX1 at 0x7f4f46d82e20>}),
#  'PldA': frozenset({<Reaction PLIPA1A120pp at 0x7f4f4688adc0>,
#             <Reaction PLIPA1A140pp at 0x7f4f468f3820>,
#             <Reaction PLIPA1A141pp at 0x7f4f4689ff70>,
#             <Reaction PLIPA1A160pp at 0x7f4f4689fee0>,
#             <Reaction PLIPA1A161pp at 0x7f4f4689ff40>,
#             <Reaction PLIPA1A180pp at 0x7f4f46953d60>,
#             <Reaction PLIPA1A181pp at 0x7f4f4696cf40>,
#             <Reaction PLIPA1E120pp at 0x7f4f46930fd0>,
#             <Reaction PLIPA1E140pp at 0x7f4f46930e80>,
#             <Reaction PLIPA1E141pp at 0x7f4f468c8b50>,
#             <Reaction PLIPA1E160pp at 0x7f4f468f39a0>,
#             <Reaction PLIPA1E161pp at 0x7f4f4688aaf0>,
#             <Reaction PLIPA1E180pp at 0x7f4f4688adf0>,
#             <Reaction PLIPA1E181pp at 0x7f4f4689f850>,
#             <Reaction PLIPA1G120pp at 0x7f4f468b5e20>,
#             <Reaction PLIPA1G140pp at 0x7f4f468b5940>,
#             <Reaction PLIPA1G141pp at 0x7f4f46849dc0>,
#             <Reaction PLIPA1G160pp at 0x7f4f46872f70>,
#             <Reaction PLIPA1G161pp at 0x7f4f46808820>,
#             <Reaction PLIPA1G180pp at 0x7f4f46808e80>,
#             <Reaction PLIPA1G181pp at 0x7f4f468305e0>,
#             <Reaction PLIPA2A120pp at 0x7f4f46860100>,
#             <Reaction PLIPA2A140pp at 0x7f4f467ead00>,
#             <Reaction PLIPA2A141pp at 0x7f4f467eab80>,
#             <Reaction PLIPA2A160pp at 0x7f4f46793970>,
#             <Reaction PLIPA2A161pp at 0x7f4f467d96d0>,
#             <Reaction PLIPA2A180pp at 0x7f4f467a7f70>,
#             <Reaction PLIPA2A181pp at 0x7f4f467bde50>,
#             <Reaction PLIPA2E120pp at 0x7f4f46779dc0>,
#             <Reaction PLIPA2E140pp at 0x7f4f4670dd30>,
#             <Reaction PLIPA2E141pp at 0x7f4f4670deb0>,
#             <Reaction PLIPA2E160pp at 0x7f4f46737c70>,
#             <Reaction PLIPA2E161pp at 0x7f4f466ccd30>,
#             <Reaction PLIPA2E180pp at 0x7f4f466ccfd0>,
#             <Reaction PLIPA2E181pp at 0x7f4f466e7df0>,
#             <Reaction PLIPA2G120pp at 0x7f4f46688b20>,
#             <Reaction PLIPA2G140pp at 0x7f4f466b2bb0>,
#             <Reaction PLIPA2G141pp at 0x7f4f46644ee0>,
#             <Reaction PLIPA2G160pp at 0x7f4f466049a0>,
#             <Reaction PLIPA2G161pp at 0x7f4f46604c70>,
#             <Reaction PLIPA2G180pp at 0x7f4f46619e50>,
#             <Reaction PLIPA2G181pp at 0x7f4f465c1f70>}),
#  'MltC': frozenset({<Reaction MLTGY1pp at 0x7f4f46b85f70>,
#             <Reaction MLTGY2pp at 0x7f4f46b85c40>,
#             <Reaction MLTGY3pp at 0x7f4f46b85c10>,
#             <Reaction MLTGY4pp at 0x7f4f46b85e80>}),
#  'CpsG': frozenset({<Reaction PMANM at 0x7f4f465d7dc0>}),
#  'EmtA': frozenset({<Reaction MLTGY1pp at 0x7f4f46b85f70>,
#             <Reaction MLTGY2pp at 0x7f4f46b85c40>,
#             <Reaction MLTGY3pp at 0x7f4f46b85c10>,
#             <Reaction MLTGY4pp at 0x7f4f46b85e80>}),
#  'Mak': frozenset({<Reaction HEX7 at 0x7f4f46d82df0>}),
#  'BioH': frozenset({<Reaction PMEACPE at 0x7f4f465ecfa0>}),
#  'HisD': frozenset({<Reaction HISTD at 0x7f4f46daad60>}),
#  'MltB': frozenset({<Reaction MLTGY1pp at 0x7f4f46b85f70>,
#             <Reaction MLTGY2pp at 0x7f4f46b85c40>,
#             <Reaction MLTGY3pp at 0x7f4f46b85c10>,
#             <Reaction MLTGY4pp at 0x7f4f46b85e80>}),
#  'CoaA': frozenset({<Reaction PNTK at 0x7f4f46595040>}),
#  'Slt': frozenset({<Reaction MLTGY1pp at 0x7f4f46b85f70>,
#             <Reaction MLTGY2pp at 0x7f4f46b85c40>,
#             <Reaction MLTGY3pp at 0x7f4f46b85c10>,
#             <Reaction MLTGY4pp at 0x7f4f46b85e80>}),
#  'MltA': frozenset({<Reaction MLTGY1pp at 0x7f4f46b85f70>,
#             <Reaction MLTGY2pp at 0x7f4f46b85c40>,
#             <Reaction MLTGY3pp at 0x7f4f46b85c10>,
#             <Reaction MLTGY4pp at 0x7f4f46b85e80>}),
#  'PanF': frozenset({<Reaction PNTOt4pp at 0x7f4f46595eb0>}),
#  'ScpB': frozenset({<Reaction MMCD at 0x7f4f46bb0d30>}),
#  'HisB': frozenset({<Reaction HISTP at 0x7f4f46daad90>,
#             <Reaction IGPDH at 0x7f4f46d82f70>}),
#  'RutC': frozenset({<Reaction POAACR at 0x7f4f465bfc70>}),
#  'HisS': frozenset({<Reaction HISTRS at 0x7f4f46daa850>}),
#  'ScpA': frozenset({<Reaction MMM2 at 0x7f4f46595e80>,
#             <Reaction MMM at 0x7f4f46bb0e50>}),
#  'MtlA': frozenset({<Reaction MNLptspp at 0x7f4f46b447f0>}),
#  'YdbK': frozenset({<Reaction POR5 at 0x7f4f46552640>}),
#  'UxuA': frozenset({<Reaction MNNH at 0x7f4f46b445e0>}),
#  'PoxB': frozenset({<Reaction POX at 0x7f4f46552cd0>}),
#  'HisJ': frozenset({<Reaction HISabcpp at 0x7f4f46daad00>}),
#  'Ppx': frozenset({<Reaction PPA2 at 0x7f4f46568cd0>,
#             <Reaction PPA at 0x7f4f46552730>}),
#  'AroP': frozenset({<Reaction HISt2rpp at 0x7f4f46d97fa0>,
#             <Reaction PHEt2rpp at 0x7f4f468f3ee0>,
#             <Reaction TRPt2rpp at 0x7f4f46604d30>,
#             <Reaction TYRt2rpp at 0x7f4f466e7f40>}),
#  'MoaD': frozenset({<Reaction MOADSUx at 0x7f4f46b58c10>,
#             <Reaction MPTS at 0x7f4f46b00d60>}),
#  'Ppa': frozenset({<Reaction PPA at 0x7f4f46552730>}),
#  'WaaA': frozenset({<Reaction MOAT2 at 0x7f4f46b587f0>,
#             <Reaction MOAT at 0x7f4f46b44f40>}),
#  'MhpC': frozenset({<Reaction HKNDDH at 0x7f4f46dbd7f0>,
#             <Reaction HKNTDH at 0x7f4f46dbdd60>}),
#  'HemC': frozenset({<Reaction HMBS at 0x7f4f46dbda90>}),
#  'ThiD': frozenset({<Reaction HMPK1 at 0x7f4f46dbd6a0>,
#             <Reaction PMPK at 0x7f4f465ecfd0>}),
#  'PutP': frozenset({<Reaction PPAt4pp at 0x7f4f46568850>,
#             <Reaction PROt4pp at 0x7f4f468f3d90>}),
#  'PdxK': frozenset({<Reaction HMPK1 at 0x7f4f46dbd6a0>,
#             <Reaction PYDAMK at 0x7f4f46830df0>,
#             <Reaction PYDXK at 0x7f4f4681ba60>,
#             <Reaction PYDXNK at 0x7f4f4681b970>}),
#  'RhtA': frozenset({<Reaction HOMt2pp at 0x7f4f46d53af0>,
#             <Reaction THRt2pp at 0x7f4f466deaf0>}),
#  'YbhA': frozenset({<Reaction MOBDabcpp at 0x7f4f46b58ac0>,
#             <Reaction PDXPP at 0x7f4f4696c970>,
#             <Reaction PYDXPP at 0x7f4f467c4f40>,
#             <Reaction SULabcpp at 0x7f4f46765e50>,
#             <Reaction TUNGSabcpp at 0x7f4f46619ac0>}),
#  'CysU': frozenset({<Reaction MOBDabcpp at 0x7f4f46b58ac0>,
#             <Reaction SELtpp at 0x7f4f4674eac0>,
#             <Reaction SLNTtpp at 0x7f4f46724fa0>,
#             <Reaction SULabcpp at 0x7f4f46765e50>,
#             <Reaction TSULabcpp at 0x7f4f46670e50>}),
#  'CysA': frozenset({<Reaction MOBDabcpp at 0x7f4f46b58ac0>,
#             <Reaction SELtpp at 0x7f4f4674eac0>,
#             <Reaction SLNTtpp at 0x7f4f46724fa0>,
#             <Reaction SULabcpp at 0x7f4f46765e50>,
#             <Reaction TSULabcpp at 0x7f4f46670e50>}),
#  'HemB': frozenset({<Reaction PPBNGS at 0x7f4f46568d90>}),
#  'CysP': frozenset({<Reaction MOBDabcpp at 0x7f4f46b58ac0>,
#             <Reaction SELtpp at 0x7f4f4674eac0>,
#             <Reaction SLNTtpp at 0x7f4f46724fa0>,
#             <Reaction SULabcpp at 0x7f4f46765e50>,
#             <Reaction TSULabcpp at 0x7f4f46670e50>}),
#  'RhtB': frozenset({<Reaction HOMt2pp at 0x7f4f46d53af0>}),
#  'Ppc': frozenset({<Reaction PPC at 0x7f4f46568f40>}),
#  'MhpE': frozenset({<Reaction HOPNTAL at 0x7f4f46d53ca0>}),
#  'Dfp': frozenset({<Reaction PPCDC at 0x7f4f4657fa90>,
#             <Reaction PPNCL2 at 0x7f4f46529f70>}),
#  'Pck': frozenset({<Reaction PPCK at 0x7f4f4657fd90>}),
#  'FolK': frozenset({<Reaction HPPK2 at 0x7f4f46d53d60>}),
#  'Sbp': frozenset({<Reaction MOBDabcpp at 0x7f4f46b58ac0>,
#             <Reaction SULabcpp at 0x7f4f46765e50>,
#             <Reaction TSULabcpp at 0x7f4f46670e50>}),
#  'ScpC': frozenset({<Reaction PPCSCT at 0x7f4f4657f7c0>}),
#  'CysW': frozenset({<Reaction MOBDabcpp at 0x7f4f46b58ac0>,
#             <Reaction SELtpp at 0x7f4f4674eac0>,
#             <Reaction SLNTtpp at 0x7f4f46724fa0>,
#             <Reaction SULabcpp at 0x7f4f46765e50>,
#             <Reaction TSULabcpp at 0x7f4f46670e50>}),
#  'ModC': frozenset({<Reaction MOBDabcpp at 0x7f4f46b58ac0>,
#             <Reaction SULabcpp at 0x7f4f46765e50>,
#             <Reaction TUNGSabcpp at 0x7f4f46619ac0>}),
#  'ModA': frozenset({<Reaction MOBDabcpp at 0x7f4f46b58ac0>,
#             <Reaction SULabcpp at 0x7f4f46765e50>,
#             <Reaction TUNGSabcpp at 0x7f4f46619ac0>}),
#  'MocA': frozenset({<Reaction MOCDS at 0x7f4f46b58d60>}),
#  'Hyi': frozenset({<Reaction HPYRI at 0x7f4f46d66ac0>}),
#  'ThrB': frozenset({<Reaction HSK at 0x7f4f46d79f70>}),
#  'MetA': frozenset({<Reaction HSST at 0x7f4f46d79d60>}),
#  'HisC': frozenset({<Reaction HSTPT at 0x7f4f46d79ca0>}),
#  'Ppk': frozenset({<Reaction PPK2 at 0x7f4f465147f0>,
#             <Reaction PPK at 0x7f4f4657ff70>}),
#  'XdhA': frozenset({<Reaction HXAND at 0x7f4f46d0fd60>,
#             <Reaction XAND at 0x7f4f465ecf70>}),
#  'DeoB': frozenset({<Reaction PPM2 at 0x7f4f46514bb0>,
#             <Reaction PPM at 0x7f4f46514f40>}),
#  'XdhB': frozenset({<Reaction HXAND at 0x7f4f46d0fd60>,
#             <Reaction XAND at 0x7f4f465ecf70>}),
#  'PanB': frozenset({<Reaction MOHMT at 0x7f4f46b6cb20>}),
#  'Mog': frozenset({<Reaction MPTAT at 0x7f4f46b44e50>}),
#  'PbpC': frozenset({<Reaction MPTG2 at 0x7f4f46b58e80>,
#             <Reaction MPTG at 0x7f4f46b583a0>}),
#  'YhfW': frozenset({<Reaction PPM at 0x7f4f46514f40>}),
#  'MurJ': frozenset({<Reaction LIPIDIIFLIP at 0x7f4f4645f0d0>,
#             <Reaction MPTG2 at 0x7f4f46b58e80>,
#             <Reaction MPTG at 0x7f4f46b583a0>}),
#  'HemG': frozenset({<Reaction PPPGO3 at 0x7f4f46529a30>,
#             <Reaction PPPGO at 0x7f4f46529a60>}),
#  'MoaE': frozenset({<Reaction MPTS at 0x7f4f46b00d60>}),
#  'XdhC': frozenset({<Reaction HXAND at 0x7f4f46d0fd60>,
#             <Reaction XAND at 0x7f4f465ecf70>}),
#  'HcaT': frozenset({<Reaction PPPNt2rpp at 0x7f4f4653d760>}),
#  'HyaC': frozenset({<Reaction HYD1pp at 0x7f4f46e21fd0>,
#             <Reaction HYD2pp at 0x7f4f46e10df0>,
#             <Reaction HYD3pp at 0x7f4f46e37e80>}),
#  'PpsA': frozenset({<Reaction PPS at 0x7f4f464d2a60>}),
#  'HybO': frozenset({<Reaction HYD1pp at 0x7f4f46e21fd0>,
#             <Reaction HYD2pp at 0x7f4f46e10df0>,
#             <Reaction HYD3pp at 0x7f4f46e37e80>}),
#  'HyaB': frozenset({<Reaction HYD1pp at 0x7f4f46e21fd0>,
#             <Reaction HYD2pp at 0x7f4f46e10df0>,
#             <Reaction HYD3pp at 0x7f4f46e37e80>}),
#  'MoeB': frozenset({<Reaction MPTSS at 0x7f4f46b6c760>}),
#  'PhoA': frozenset({<Reaction PPTHpp at 0x7f4f464d2460>}),
#  'HyaA': frozenset({<Reaction HYD1pp at 0x7f4f46e21fd0>,
#             <Reaction HYD2pp at 0x7f4f46e10df0>,
#             <Reaction HYD3pp at 0x7f4f46e37e80>}),
#  'PurD': frozenset({<Reaction PRAGSr at 0x7f4f46930c40>}),
#  'RutE': frozenset({<Reaction MSAR at 0x7f4f46b00df0>}),
#  'PurM': frozenset({<Reaction PRAIS at 0x7f4f46930820>}),
#  'FolD': frozenset({<Reaction MTHFC at 0x7f4f46b29eb0>,
#             <Reaction MTHFD at 0x7f4f46b29af0>}),
#  'HybA': frozenset({<Reaction HYD1pp at 0x7f4f46e21fd0>,
#             <Reaction HYD2pp at 0x7f4f46e10df0>,
#             <Reaction HYD3pp at 0x7f4f46e37e80>}),
#  'HisI': frozenset({<Reaction PRAMPC at 0x7f4f468c8d90>,
#             <Reaction PRATPP at 0x7f4f468c8d00>}),
#  ...}

# %%
one= pd.read_csv("one feasible value reactions.csv")
flat= pd.read_csv("flat.csv")
diff_saturated= pd.read_csv("diff_saturated.csv")
Ushaped= pd.read_csv("Ushaped_reactions.csv")
monotonically_increasingANDstable_reactions= pd.read_csv("monotonically increasing and stable reactions.csv")
monotonically_increasing_only_reactions= pd.read_csv("monotonically increasing only reactions.csv")
monotonically_decreasingANDstable_reactions= pd.read_csv("monotonically decreasing and stable reactions.csv")
monotonically_decreasing_only_reactions= pd.read_csv("monotonically decreasing only reactions.csv")
increasingANDdecreasingANDstable_reactions= pd.read_csv("increasing and decreasing and stable reactions.csv")
increasingANDdecreasing_only_reactions= pd.read_csv("increasing and decreasing only reactions.csv")

# %%
import csv

with open('dictionary.csv', 'w') as f:  
    writer = csv.writer(f)
    for k, v in dictionary.items():
       writer.writerow([k, v])

# %%
import pandas as pd
p= pd.read_csv('dictionary.csv', header= None)
p

headerList= ["Gene name", "Reaction"]
p.to_csv("dictionary_NEW.csv", header=headerList, index=False)
p2 = pd.read_csv("dictionary_NEW.csv")
print('\nModified file:')
print(p2)
# Out:
# Modified file:
#        Gene name                                           Reaction
# 0           PhoE  frozenset({<Reaction FE3tex at 0x7f4f46f901f0>...
# 1           YlbA  frozenset({<Reaction UGCIAMH at 0x7f4f4642f8b0>})
# 2           OmpC  frozenset({<Reaction FE3tex at 0x7f4f46f901f0>...
# 3           OmpF  frozenset({<Reaction FE3tex at 0x7f4f46f901f0>...
# 4           OmpN  frozenset({<Reaction FE3tex at 0x7f4f46f901f0>...
# ...          ...                                                ...
# 1339        YcjT      frozenset({<Reaction MPL at 0x7f4f46404fa0>})
# 1340        YafJ     frozenset({<Reaction ASNO at 0x7f4f46419e20>})
# 1341        YgdH    frozenset({<Reaction PYRDC at 0x7f4f46470df0>})
# 1342  Locus 3025  frozenset({<Reaction HPA3MOFAD at 0x7f4f46419f...
# 1343        YcjM     frozenset({<Reaction SUCP at 0x7f4f4642f9d0>})
#
# [1344 rows x 2 columns]

# %%
boolean_findings = p2['Reaction'].str.contains('UGCIAMH')

boolean_findings

i=0
gene_names= list()
while i <1343:
    if boolean_findings[i] ==True:
        
        l= p2.iloc[i, 0]
        gene_names.append(l)
    i=i+1
gene_names
# Out:
# ['YlbA']

# %%
diff_saturated["Reaction names"]
# Out:
# 0          EX_ppt_e
# 1          EX_fe2_e
# 2     ACOLIPAabctex
# 3               ADA
# 4               ADD
#           ...
# 87              POX
# 88              PPK
# 89              PPM
# 90    L_LACD2_copy2
# 91      XTSNH_copy2
# Name: Reaction names, Length: 92, dtype: object

# %%
z=0
saturated_gene_names= list()
l= str()

while z< len(diff_saturated):

    boolean_findings = p2['Reaction'].str.contains(diff_saturated["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            saturated_gene_names.append(l)
        i=i+1
    
    z=z+1

saturated_gene_names
# Out:
# ['LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'Add',
#  'LpxC',
#  'RffT',
#  'Ade',
#  'LigA',
#  'NudC',
#  'Adk',
#  'RihC',
#  'Apt',
#  'Amn',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'CarA',
#  'CarB',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'Add',
#  'CopA',
#  'CydD',
#  'CydC',
#  'PtsH',
#  'PtsI',
#  'DhaK',
#  'DhaL',
#  'DhaM',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'YbiV',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'AcpH',
#  'FdnI',
#  'FdnG',
#  'FdoI',
#  'FdnH',
#  'FdoG',
#  'FdoH',
#  'FadK',
#  'FadD',
#  'AnsB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NadB',
#  'YbiV',
#  'NadB',
#  'NadB',
#  'MglC',
#  'MglA',
#  'MglB',
#  'YtfR',
#  'YtfT',
#  'MglC',
#  'MglA',
#  'YjfF',
#  'YtfQ',
#  'MglB',
#  'PabB',
#  'AnsB',
#  'YbaS',
#  'YneH',
#  'NudK',
#  'YehX',
#  'YehW',
#  'YehY',
#  'OsmF',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'GhrB',
#  'GhrA',
#  'AtoA',
#  'AtoD',
#  'Gpt',
#  'Hpt',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'Glk',
#  'Mak',
#  'ZntA',
#  'RihC',
#  'Gsk',
#  'LldD',
#  'YkgF',
#  'YkgE',
#  'YkgG',
#  'LldD',
#  'YkgF',
#  'YkgE',
#  'YkgG',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'MaeA',
#  'MalZ',
#  'MalZ',
#  'MalZ',
#  'ScpA',
#  'YbiV',
#  'MgtA',
#  'AcnB',
#  'Gsk',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'NapA',
#  'NapC',
#  'NapB',
#  'Dgt',
#  'Dgt',
#  'Gpp',
#  'Eda',
#  'PfkA',
#  'PfkB',
#  'PfkA',
#  'Gpt',
#  'Hpt',
#  'YbiV',
#  'AphA',
#  'SodA',
#  'SodB',
#  'SodC',
#  'SucD',
#  'SucC',
#  'DsdA',
#  'TnaA',
#  'SdaA',
#  'TdcG',
#  'SdaB',
#  'TrpA',
#  'TrpB',
#  'Upp',
#  'RihC',
#  'RihA',
#  'RihB',
#  'Udk',
#  'RihC',
#  'LldD',
#  'XylH',
#  'XylG',
#  'XylF',
#  'ScpA',
#  'PoxB',
#  'SolA',
#  'FolK',
#  'Ppk',
#  'DeoB',
#  'YhfW',
#  'LeuC',
#  'LeuD',
#  'LldD',
#  'RihC',
#  'RihA',
#  'RihB']

# %%
z=0
one_gene_names= list()
l= str()

while z< len(one):

    boolean_findings = p2['Reaction'].str.contains(one['1 feasible value'][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            one_gene_names.append(l)
        i=i+1
    
    z=z+1

one_gene_names
# Out:
# ['LamB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'MhpA',
#  'RffT',
#  'MalS',
#  'MhpA',
#  'LyxK',
#  'BglA',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'CpdB',
#  'FabG',
#  'AtoE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FabG',
#  'FabG',
#  'NhoA',
#  'CobU',
#  'FabB',
#  'FabF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Rfe',
#  'FabB',
#  'FabF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TynA',
#  'PtsH',
#  'NagE',
#  'Crr',
#  'PtsG',
#  'PtsI',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ThrC',
#  'IlvN',
#  'IlvI',
#  'IlvH',
#  'IlvB',
#  'RffM',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'Crr',
#  'PtsI',
#  'MurP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NanT',
#  'Mtn',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GutQ',
#  'KdsD',
#  'OmpC',
#  'OmpF',
#  'Deleted',
#  'NanA',
#  'FadE',
#  'FadE',
#  'FadE',
#  'S0001',
#  'Tam',
#  'CusA',
#  'CusF',
#  'CusC',
#  'CusB',
#  'Mtn',
#  'Aas',
#  'AcpP',
#  'AcpT',
#  'AcpS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PabC',
#  'PabA',
#  'PabB',
#  'AlaS',
#  'SpeD',
#  'NupC',
#  'NupG',
#  'Tsx',
#  'CobU',
#  'CobS',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'AlsK',
#  'RpiB',
#  'AlsE',
#  'AlsC',
#  'AlsB',
#  'AlsA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TrpD',
#  'TrpE',
#  'GlpE',
#  'PspE',
#  'UxaA',
#  'MalQ',
#  'NanE',
#  'NanK',
#  'RfaD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BioA',
#  'UbiE',
#  'ThiC',
#  'PepB',
#  'PepA',
#  'PepN',
#  'PepD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'BioF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TrpD',
#  'ApaH',
#  'AspS',
#  'SpeE',
#  'ArsC',
#  'GrxB',
#  'QueF',
#  'IspE',
#  'Cfa',
#  'Cfa',
#  'Cfa',
#  'HisG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Cfa',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MoeA',
#  'MobB',
#  'MobA',
#  'MobB',
#  'MobA',
#  'BetA',
#  'PheA',
#  'TyrA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BioB',
#  'AroC',
#  'MenF',
#  'EntC',
#  'UbiC',
#  'PtsI',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TauB',
#  'TauC',
#  'TauA',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'HcaF',
#  'HcaD',
#  'HcaE',
#  'HcaC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AtoE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MobB',
#  'MobA',
#  'MobB',
#  'MobA',
#  'MoeA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CadB',
#  'BtuR',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'BtuD',
#  'BtuF',
#  'BtuC',
#  'ExbD',
#  'ExbB',
#  'BtuB',
#  'TonB',
#  'BtuR',
#  'ClcB',
#  'ClcA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'QueC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GldA',
#  'LpxT',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'MsbA',
#  'RibD',
#  'MoaC',
#  'MoaA',
#  'HemF',
#  'HemN',
#  'HemN',
#  'CaiB',
#  'CaiD',
#  'CaiB',
#  'AraA',
#  'CaiD',
#  'CaiC',
#  'QueD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CaiT',
#  'NupC',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Tsx',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YgeX',
#  'LysA',
#  'DapF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RibB',
#  'BioD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlpE',
#  'PspE',
#  'PspE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CynS',
#  'CynX',
#  'ChbF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FadL',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupC',
#  'NupG',
#  'Tsx',
#  'FadL',
#  'DgoK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CsdA',
#  'KdgT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MetC',
#  'MalY',
#  'CysS',
#  'AroG',
#  'AroF',
#  'AroH',
#  'DgoA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IlvD',
#  'PtsH',
#  'PtsI',
#  'AscF',
#  'BglF',
#  'NupC',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'EntA',
#  'HcaB',
#  'MhpB',
#  'MhpB',
#  'DapB',
#  'AroD',
#  'DapA',
#  'FolC',
#  'FolM',
#  'MenA',
#  'MenB',
#  'YbgC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DkgB',
#  'DkgA',
#  'FolB',
#  'IspA',
#  'RibD',
#  'HcaB',
#  'UbiG',
#  'RibD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FolP',
#  'S0001',
#  'NfsB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NudB',
#  'MutT',
#  'NfsB',
#  'FolX',
#  'AroB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CoaE',
#  'NudF',
#  'NudE',
#  'IlvC',
#  'PanE',
#  'DapB',
#  'NadC',
#  'WzyE',
#  'WzzE',
#  'WzyE',
#  'WzzE',
#  'WzyE',
#  'WzzE',
#  'WzxE',
#  'DsbC',
#  'TrxA',
#  'TrxC',
#  'DsbD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FumB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupC',
#  'NupG',
#  'Tsx',
#  'LpxL',
#  'LpxM',
#  'LpxP',
#  'LpxM',
#  'FabI',
#  'ArgS',
#  'Dxr',
#  'Dxs',
#  'XylB',
#  'Epd',
#  'GapA',
#  'FabI',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UlaG',
#  'FadK',
#  'FadD',
#  'PtsH',
#  'PtsI',
#  'UlaC',
#  'UlaB',
#  'UlaA',
#  'FrmA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'FadK',
#  'FadD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'FucI',
#  'FucK',
#  'FucA',
#  'YgbL',
#  'HemH',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'SsuD',
#  'Fmt',
#  'FecB',
#  'FecD',
#  'FecC',
#  'FecE',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FecA',
#  'FepG',
#  'FepC',
#  'FepD',
#  'FepB',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'CirA',
#  'Fiu',
#  'RibF',
#  'AsnS',
#  'Frc',
#  'FruK',
#  'FrlB',
#  'FrlC',
#  'FrlD',
#  'FrlA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GntP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'FruB',
#  'FruA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ArsB',
#  'Agp',
#  'RffH',
#  'RfbA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'SuhB',
#  'AphA',
#  'YihU',
#  'PanD',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Maa',
#  'UhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Agp',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GarL',
#  'GudX',
#  'GudD',
#  'GudP',
#  'GarP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GarD',
#  'YjjN',
#  'DgoD',
#  'YjjL',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RfaG',
#  'RfaI',
#  'DgoT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GudP',
#  'GarP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ExuT',
#  'KdgT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GalK',
#  'WcaK',
#  'GalM',
#  'MelA',
#  'PtsH',
#  'PtsI',
#  'GatC',
#  'GatA',
#  'GatB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ExuT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlnS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GatD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AldA',
#  'Fcl',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UxaC',
#  'UxaC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'IscU',
#  'IscS',
#  'IscU',
#  'IscS',
#  'CyaY',
#  'UbiA',
#  'MhpT',
#  'IscU',
#  'IscS',
#  'CyaY',
#  'IscU',
#  'IscA',
#  'IscU',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IscU',
#  'IscA',
#  'FadL',
#  'FadL',
#  'EntB',
#  'CyoE',
#  'IscS',
#  'RfaP',
#  'RfaY',
#  'RfaC',
#  'RfaF',
#  'HisF',
#  'HisH',
#  'RfaQ',
#  'ThiM',
#  'HisB',
#  'TrpC',
#  'IlvE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IleS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'HisD',
#  'HisB',
#  'HisS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MhpC',
#  'MhpC',
#  'HemC',
#  'ThiD',
#  'PdxK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YidK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NupG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Tsx',
#  'Idi',
#  'MhpE',
#  'FolK',
#  'MhpB',
#  'MhpT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LeuB',
#  'LeuC',
#  'LeuD',
#  'LeuC',
#  'LeuD',
#  'LeuA',
#  'TauB',
#  'TauC',
#  'TauA',
#  'SsuA',
#  'SsuC',
#  'SsuB',
#  'MetA',
#  'HisC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MsbA',
#  'LptF',
#  'LptC',
#  'LptB',
#  'LptA',
#  'LptG',
#  'IlvC',
#  'KdsB',
#  'GlyQ',
#  'GlyS',
#  'KdsC',
#  'KdsA',
#  'YiaQ',
#  'UlaD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ArnT',
#  'BglX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YjdL',
#  'DtpA',
#  'DtpB',
#  'DtpD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YjdL',
#  'DtpA',
#  'DtpB',
#  'DtpD',
#  'Gmd',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'TyrB',
#  'IlvE',
#  'LeuS',
#  'RfaE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MsbA',
#  ...]

# %%
z=0
flat_gene_names= list()
l= str()

while z< len(flat):

    boolean_findings = p2['Reaction'].str.contains(flat["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            flat_gene_names.append(l)
        i=i+1
    
    z=z+1

flat_gene_names
# Out:
# ['GhrB',
#  'GhrB',
#  'GhrB',
#  'GabP',
#  'FadA',
#  'AtoB',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'Acs',
#  'IlvN',
#  'IlvI',
#  'IlvH',
#  'IlvB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Acs',
#  'EamA',
#  'EamB',
#  'GlcA',
#  'LldP',
#  'ActP',
#  'GlyA',
#  'LtaE',
#  'AlaA',
#  'AlaC',
#  'CycA',
#  'YaaJ',
#  'Adk',
#  'Adk',
#  'FeaB',
#  'MalQ',
#  'MalQ',
#  'MalQ',
#  'GltP',
#  'BetB',
#  'BisC',
#  'ChaA',
#  'YrbG',
#  'CaiC',
#  'ProP',
#  'CaiT',
#  'CaiC',
#  'FadB',
#  'FadB',
#  'FadB',
#  'CueO',
#  'IlvD',
#  'DadA',
#  'FolB',
#  'PyrD',
#  'GhrB',
#  'GhrB',
#  'IspH',
#  'FabI',
#  'FabI',
#  'FabI',
#  'DsbB',
#  'DsbA',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'FabI',
#  'CysI',
#  'CysJ',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'SsuE',
#  'Fau',
#  'GlgB',
#  'GlgP',
#  'MalP',
#  'GlgP',
#  'MalP',
#  'GlgA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'LamB',
#  'GlgX',
#  'GlgC',
#  'GadC',
#  'GltP',
#  'GltS',
#  'GlxK',
#  'GarK',
#  'GlcA',
#  'LldP',
#  'ActP',
#  'FadJ',
#  'FadB',
#  'HycC',
#  'HycG',
#  'HycE',
#  'HycD',
#  'HycF',
#  'HycB',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'MenF',
#  'EntC',
#  'TolC',
#  'AcrF',
#  'AcrE',
#  'Mtr',
#  'IspH',
#  'Hyi',
#  'GhrB',
#  'GhrA',
#  'IlvC',
#  'FabB',
#  'FabF',
#  'FabH',
#  'CycA',
#  'YeaV',
#  'YaaJ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'FldB',
#  'FldA',
#  'IspG',
#  'NarH',
#  'NarG',
#  'NarY',
#  'NarW',
#  'NarZ',
#  'NarV',
#  'NarI',
#  'NarJ',
#  'ChaA',
#  'MdfA',
#  'Adk',
#  'Ndk',
#  'Hmp',
#  'NorV',
#  'NorW',
#  'LplA',
#  'PdxH',
#  'ProP',
#  'PutP',
#  'YgiN',
#  'PhnN',
#  'Sad',
#  'Deleted',
#  'SdaC',
#  'SstT',
#  'GlyA',
#  'GlyA',
#  'LtaE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Deleted',
#  'YdfG',
#  'CydD',
#  'CydC',
#  'Ggt',
#  'GsiA',
#  'GsiB',
#  'GsiC',
#  'GsiD',
#  'Tdh',
#  'IlvA',
#  'TrpA',
#  'TrpB',
#  'GlxR',
#  'GarR',
#  'UraA',
#  'RutG',
#  'AvtA',
#  'IlvE',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcnB',
#  'MenB',
#  'FadB',
#  'FadB',
#  'AvtA',
#  'ScpC',
#  'GhrB',
#  'FeaB',
#  'FolB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'AraE',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'YdeA',
#  'FadJ',
#  'FadB',
#  'FadB',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'FadA',
#  'FadI',
#  'YiaK']

# %%
z=0
Ushaped_gene_names= list()
l= str()

while z< len(Ushaped):

    boolean_findings = p2['Reaction'].str.contains(Ushaped["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            Ushaped_gene_names.append(l)
        i=i+1
    
    z=z+1

Ushaped_gene_names
# Out:
# ['Deleted',
#  'PurT',
#  'AckA',
#  'AsnB',
#  'CueO',
#  'PurT',
#  'GltD',
#  'GltB',
#  'GarK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'NrfC',
#  'NrfD',
#  'NrfA',
#  'NrfB',
#  'NrfC',
#  'NrfD',
#  'NrfA',
#  'NrfB',
#  'Prs',
#  'Pta',
#  'EutD',
#  'YbhA',
#  'CysU',
#  'CysA',
#  'CysP',
#  'Sbp',
#  'CysW',
#  'ModC',
#  'ModA',
#  'HemF',
#  'HemN',
#  'HemG']

# %%
z=0
monotonically_increasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasingANDstable_reactions_gene_names
# Out:
# ['ProP',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorY',
#  'TorZ',
#  'DsbB',
#  'DsbA',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'HyaC',
#  'HybO',
#  'HyaB',
#  'HyaA',
#  'HybA',
#  'HybB',
#  'HybC',
#  'NarH',
#  'NarG',
#  'NarY',
#  'NarW',
#  'NarZ',
#  'NarV',
#  'NarI',
#  'NarJ',
#  'YgiN',
#  'DmsA',
#  'YnfH',
#  'DmsB',
#  'YnfE',
#  'YnfF',
#  'DmsC',
#  'YnfG',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'DmsA',
#  'DmsB',
#  'DmsC',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'TorY',
#  'TorZ',
#  'TorC',
#  'TorA',
#  'IspG',
#  'PreB',
#  'PreA']

# %%
z=0
monotonically_increasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_increasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_increasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_increasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_increasing_only_reactions_gene_names
# Out:
# ['PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GhrB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AtoA',
#  'AtoD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'IdnO',
#  'IdnT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcpP',
#  'FabH',
#  'KgtP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'XanP',
#  'PurP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Adk',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FrmA',
#  'AdhE',
#  'FrmA',
#  'AdhP',
#  'AldB',
#  'YbbW',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Lpp',
#  'Lnt',
#  'Lpp',
#  'Lnt',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YdfG',
#  'CycA',
#  'BetT',
#  'YeaV',
#  'BetB',
#  'BisC',
#  'AtoA',
#  'AtoD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CodB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ProP',
#  'CusA',
#  'CusF',
#  'CusC',
#  'CusB',
#  'KdgK',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlcA',
#  'LldP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FolA',
#  'FolM',
#  'AdiC',
#  'YiaK',
#  'FabI',
#  'FabI',
#  'YdfG',
#  'CycA',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'FadJ',
#  'FadB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'FabI',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AnsP',
#  'PtsH',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DctA',
#  'HemL',
#  'AphA',
#  'PyrI',
#  'PyrB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'NadB',
#  'PtsH',
#  'Crr',
#  'PtsG',
#  'PtsI',
#  'ManY',
#  'ManZ',
#  'ManX',
#  'MalX',
#  'GlnQ',
#  'GlnP',
#  'GlnH',
#  'GalP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AnsB',
#  'HemA',
#  'GltX',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlpF',
#  'YeaV',
#  'ProP',
#  'Tsx',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GudP',
#  'GarP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'IdnT',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AtoE',
#  'FieF',
#  'BrnQ',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AroP',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlcA',
#  'LldP',
#  'LacZ',
#  'BglX',
#  'PldB',
#  'PldB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'BrnQ',
#  'LipB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FtsI',
#  'MrcB',
#  'MrcA',
#  'MrdA',
#  'GlpQ',
#  'MalP',
#  'MalP',
#  'MalP',
#  'MrcB',
#  'MrcA',
#  'PbpC',
#  'MurJ',
#  'Hmp',
#  'PnuC',
#  'UbiF',
#  'PyrF',
#  'UbiH',
#  'UbiB',
#  'DctA',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'PgpB',
#  'YqaB',
#  'Pgm',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AphA',
#  'AraB',
#  'AphA',
#  'PotE',
#  'AlsC',
#  'AlsB',
#  'AlsA',
#  'YtfR',
#  'YtfT',
#  'YjfF',
#  'YtfQ',
#  'RbsC',
#  'RbsA',
#  'RbsD',
#  'RbsB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'DcuB',
#  'FumB',
#  'DmlA',
#  'TtdA',
#  'TtdB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'YeiG',
#  'FrmB',
#  'CysU',
#  'CysA',
#  'CysP',
#  'CysW',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ThyA',
#  'PtsH',
#  'Crr',
#  'PtsI',
#  'TreB',
#  'TrpA',
#  'TrpB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'CpsG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GlpF',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'BrnQ',
#  'YgaH',
#  'YgaZ',
#  'XylE',
#  'PutP',
#  'HemG',
#  'GhrB',
#  'DmlA']

# %%
z=0
monotonically_decreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasingANDstable_reactions_gene_names
# Out:
# ['DdpX',
#  'GlyA',
#  'LtaE',
#  'DdpA',
#  'DdpB',
#  'DdpD',
#  'DdpC',
#  'DppF',
#  'DdpF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'PuuC',
#  'AldB',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'DctA',
#  'DcuA',
#  'DcuB',
#  'ZntA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'ZntA',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'ProX',
#  'ProV',
#  'ProW',
#  'AppC',
#  'AppB',
#  'AppC',
#  'AppB',
#  'CydB',
#  'CydA',
#  'AraG',
#  'AraF',
#  'AraH',
#  'YdeA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'ArtM',
#  'ArtJ',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'ArtP',
#  'ArtI',
#  'ArtQ',
#  'FeoB',
#  'MntH',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'GlpA',
#  'GlpD',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'GlpA',
#  'GlpB',
#  'GlpC',
#  'AspA',
#  'AspC',
#  'AspS',
#  'GltJ',
#  'GltK',
#  'GltI',
#  'GltL',
#  'XanP',
#  'IdnD',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'HisJ',
#  'GhrB',
#  'GhrA',
#  'YdeA',
#  'SetB',
#  'SetA',
#  'Dld',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'LivK',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'DcuA',
#  'DcuB',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'Mqo',
#  'Mqo',
#  'CorA',
#  'Ndh',
#  'Ndh',
#  'Ndh',
#  'MdaB',
#  'MdaB',
#  'MdaB',
#  'PntA',
#  'PntB',
#  'SthA',
#  'NhaB',
#  'NhaA',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'ZntA',
#  'BtuE',
#  'HscC',
#  'RsgA',
#  'YjjX',
#  'RsgA',
#  'YjjX',
#  'RsgA',
#  'AppA',
#  'RsgA',
#  'MutT',
#  'MazG',
#  'RdgB',
#  'MutT',
#  'MazG',
#  'NudI',
#  'MazG',
#  'NudG',
#  'MazG',
#  'NudG',
#  'NudB',
#  'MazG',
#  'MazG',
#  'NudI',
#  'MazG',
#  'MazG',
#  'HisP',
#  'HisM',
#  'HisQ',
#  'ArgT',
#  'ProX',
#  'ProV',
#  'ProW',
#  'PotD',
#  'PotB',
#  'PotF',
#  'YdcS',
#  'YdcV',
#  'PotA',
#  'PotI',
#  'PotH',
#  'PotG',
#  'PotC',
#  'YdcU',
#  'YdcT',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'DcuA',
#  'DcuB',
#  'TrxA',
#  'TrxC',
#  'BtuE',
#  'Bcp',
#  'GlyA',
#  'LtaE',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'AcrD',
#  'AcrA',
#  'AcrB',
#  'TolC',
#  'XanP',
#  'XanQ',
#  'LivJ',
#  'LivM',
#  'LivF',
#  'LivH',
#  'LivG',
#  'ZntA',
#  'Ppx',
#  'SurE',
#  'AraG',
#  'AraF',
#  'AraH']

# %%
z=0
monotonically_decreasing_only_reactions_gene_names= list()
l= str()

while z< len(monotonically_decreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(monotonically_decreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            monotonically_decreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

monotonically_decreasing_only_reactions_gene_names
# Out:
# ['LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'LplT',
#  'NudJ',
#  'Cof',
#  'FabA',
#  'FabZ',
#  'RutD',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'Aas',
#  'AcpP',
#  'FabA',
#  'FabZ',
#  'FabA',
#  'FabZ',
#  'Aas',
#  'AcpP',
#  'GabT',
#  'PuuE',
#  'Prr',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabG',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabB',
#  'FabB',
#  'FabF',
#  'FabB',
#  'FabB',
#  'FabF',
#  'FabF',
#  'NagK',
#  'OppF',
#  'MppA',
#  'OppB',
#  'OppC',
#  'OppD',
#  'MurQ',
#  'FadE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'FadE',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'PlsC',
#  'AcpP',
#  'PlsX',
#  'AcpP',
#  'PlsX',
#  'EamA',
#  'EamB',
#  'YcjG',
#  'CyaA',
#  'NudF',
#  'NudE',
#  'AllC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AllB',
#  'YbbW',
#  'NagA',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'DkgB',
#  'DkgA',
#  'Gpr',
#  'YeaE',
#  'GldA',
#  'AmpD',
#  'NagZ',
#  'AmpG',
#  'NagZ',
#  'RfaD',
#  'SpeB',
#  'AmpG',
#  'PlsC',
#  'PlsC',
#  'S0001',
#  'PlsC',
#  'PepB',
#  'PepA',
#  'PepN',
#  'PepD',
#  'AnmK',
#  'PlsC',
#  'ApaH',
#  'LysU',
#  'PlsY',
#  'PlsY',
#  'PlsY',
#  'AstA',
#  'S0001',
#  'PlsY',
#  'DppF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'PlsY',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'YbhO',
#  'Cls',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'ZupT',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuE',
#  'CodA',
#  'CdsA',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'CdsA',
#  'CdsA',
#  'ZntA',
#  'S0001',
#  'CdsA',
#  'CdsA',
#  'S0001',
#  'Cdd',
#  'EntE',
#  'PyrC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DeoC',
#  'YdgI',
#  'Eda',
#  'RhmA',
#  'Edd',
#  'PreB',
#  'PreA',
#  'NudI',
#  'Dut',
#  'EntD',
#  'EutB',
#  'EutC',
#  'ArgO',
#  'TesB',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FbaA',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'FadK',
#  'FadD',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'S0001',
#  'FieF',
#  'YtfE',
#  'HycC',
#  'HycG',
#  'HycE',
#  'HyfI',
#  'HycD',
#  'HycF',
#  'HyfE',
#  'HycB',
#  'HyfC',
#  'HyfJ',
#  'FdhF',
#  'HyfF',
#  'HyfG',
#  'HyfA',
#  'HyfB',
#  'HyfH',
#  'HyfD',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'FocB',
#  'FocA',
#  'Fre',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FhuA',
#  'FepG',
#  'FepC',
#  'FepD',
#  'FepB',
#  'S0001',
#  'TolC',
#  'ExbD',
#  'ExbB',
#  'TonB',
#  'FepA',
#  'EntS',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'FhuB',
#  'FhuC',
#  'FhuD',
#  'S0001',
#  'ProA',
#  'NagB',
#  'Zwf',
#  'Gcd',
#  'YliI',
#  'IdnT',
#  'KdgT',
#  'GntP',
#  'GntT',
#  'GntU',
#  'GalU',
#  'ProB',
#  'GshA',
#  'Gcl',
#  'PuuC',
#  'PuuD',
#  'PuuB',
#  'PuuA',
#  'S0001',
#  'RhtA',
#  'RhtB',
#  'GloB',
#  'TesA',
#  'TesA',
#  'ChaA',
#  'KefC',
#  'KefB',
#  'MdfA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'PldB',
#  'MpaA',
#  'PepD',
#  'AldA',
#  'FucO',
#  'LacY',
#  'S0001',
#  'GloA',
#  'TesA',
#  'YdfG',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'ArgO',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'TesA',
#  'PrpD',
#  'PrpB',
#  'PrpC',
#  'CpsB',
#  'MrcB',
#  'MrcA',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'DacC',
#  'DacB',
#  'DacD',
#  'DacA',
#  'DacB',
#  'PbpG',
#  'MepA',
#  'DacB',
#  'PbpG',
#  'MepA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'UgpQ',
#  'GlpQ',
#  'MelB',
#  'YdeA',
#  'GlpQ',
#  'S0001',
#  'Deleted',
#  'MltC',
#  'EmtA',
#  'MltB',
#  'Slt',
#  'MltA',
#  'S0001',
#  'ScpB',
#  'TrxA',
#  'TrxC',
#  'BisC',
#  'MsrA',
#  'TrxA',
#  'TrxC',
#  'MsrB',
#  'ZitB',
#  'FieF',
#  'UgpQ',
#  'GlpQ',
#  'LigA',
#  'NudC',
#  'YdfG',
#  'RutE',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'PncB',
#  'Gss',
#  'Gss',
#  'Adk',
#  'Ndk',
#  'S0001',
#  'AphA',
#  'SurE',
#  'UshA',
#  'Gor',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'Ggt',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'UshA',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'PncA',
#  'CydD',
#  'CydC',
#  'TdcE',
#  'PflA',
#  'YfiD',
#  'PflB',
#  'RdgB',
#  'RdgB',
#  'GshB',
#  'RdgB',
#  'RelA',
#  'S0001',
#  'PyrE',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'SerA',
#  'PldA',
#  'DosP',
#  'CpdB',
#  'DosP',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'YbhA',
#  'MsbA',
#  'MsbA',
#  'PldA',
#  'MsbA',
#  'MsbA',
#  'MsbA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'MsbA',
#  'PldA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PgpB',
#  'PgpA',
#  'PldA',
#  'PgsA',
#  'PgsA',
#  'PldA',
#  'PgsA',
#  'PgsA',
#  'PgsA',
#  'PgsA',
#  'PgsA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'Psd',
#  'PldA',
#  'Psd',
#  'Psd',
#  'PldA',
#  'PldA',
#  'PldA',
#  'Psd',
#  'PldA',
#  'Psd',
#  'SerC',
#  'AphA',
#  'SerB',
#  'PldA',
#  'PssA',
#  'PssA',
#  'PssA',
#  'PldA',
#  'PldA',
#  'PssA',
#  'PssA',
#  'RbsK',
#  'AraB',
#  'S0001',
#  'PatA',
#  'PldA',
#  'PldA',
#  'Deleted',
#  'DeoD',
#  'PldA',
#  'Deleted',
#  'DeoD',
#  'PdxH',
#  'PdxK',
#  'PdxK',
#  'PdxY',
#  'PdxK',
#  'PldA',
#  'Cof',
#  'YbhA',
#  'YigL',
#  'RutF',
#  'RutA',
#  'PldA',
#  'PotD',
#  'PotB',
#  'YdcS',
#  'YdcV',
#  'PotA',
#  'PotC',
#  'YdcU',
#  'YdcT',
#  'MdtJ',
#  'MdtI',
#  'PldA',
#  'PldA',
#  'AstB',
#  'PldA',
#  'PldA',
#  'PldA',
#  'PldA',
#  'EntF',
#  'FabA',
#  'PldA',
#  'AstE',
#  'PldA',
#  'AstD',
#  'PldA',
#  'NudJ',
#  'IspB',
#  'RffC',
#  'RffA',
#  'RfbC',
#  'RfbD',
#  'RfbB',
#  'RffG',
#  'PldA',
#  'AstC',
#  'PldA',
#  'PldA',
#  'RhtA',
#  'RhtC',
#  'PldA',
#  'PldA',
#  'DeoA',
#  'PldA',
#  'TrxA',
#  'TrxC',
#  'TrxB',
#  'OtsB',
#  'OtsA',
#  'PldA',
#  'TreF',
#  'TreA',
#  'TnaA',
#  'PldA',
#  'PldA',
#  'LdcA',
#  'PldA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Mpl',
#  'RutB',
#  'PldA',
#  'AllD',
#  'XdhA',
#  'XdhB',
#  'XdhC',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RutC',
#  'SpoT',
#  'DeoB',
#  'FldB',
#  'FldA',
#  'Fpr']

# %%
z=0
increasingANDdecreasingANDstable_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasingANDstable_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasingANDstable_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasingANDstable_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasingANDstable_reactions_gene_names
# Out:
# ['YgdH',
#  'IaaA',
#  'AnsA',
#  'AnsB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'S0001',
#  'OmpL',
#  'OmpG',
#  'OmpA',
#  'CitE',
#  'CitF',
#  'CitD',
#  'CitX',
#  'PrpB',
#  'Pgi',
#  'FdnI',
#  'FdnG',
#  'FdoI',
#  'FdnH',
#  'FdoG',
#  'FdoH',
#  'MaeB',
#  'FrdC',
#  'FrdB',
#  'FrdD',
#  'FrdA',
#  'PstA',
#  'PstB',
#  'PstS',
#  'PstC',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'PyrD',
#  'SpeA',
#  'Deleted',
#  'KdpB',
#  'KdpC',
#  'KdpA',
#  'NuoC',
#  'NuoE',
#  'NuoM',
#  'NuoH',
#  'NuoF',
#  'NuoB',
#  'NuoA',
#  'NuoL',
#  'NuoG',
#  'NuoK',
#  'NuoJ',
#  'NuoN',
#  'NuoI',
#  'ZnuC',
#  'ZnuA',
#  'ZnuB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcpP',
#  'PlsX',
#  'NudB',
#  'MutT',
#  'Cdh',
#  'GmhB',
#  'Ppx',
#  'Ppa',
#  'PutP',
#  'SurE',
#  'Lpd',
#  'FldB',
#  'FldA',
#  'Zwf',
#  'AceF',
#  'AceE',
#  'IspG',
#  'HisB',
#  'NapG',
#  'NapA',
#  'NapC',
#  'NapB',
#  'NapH',
#  'PntA',
#  'PntB',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'GlcD',
#  'GlcF',
#  'GlcE',
#  'GlyA',
#  'LtaE',
#  'SdhD',
#  'SdhA',
#  'SdhB',
#  'SdhC',
#  'MgtA',
#  'NikC',
#  'NikE',
#  'NikD',
#  'NikB',
#  'NikA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AdhE',
#  'MhpF',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'MntH',
#  'NirB',
#  'NirD']

# %%
z=0
increasingANDdecreasing_only_reactions_gene_names= list()
l= str()

while z< len(increasingANDdecreasing_only_reactions):

    boolean_findings = p2['Reaction'].str.contains(increasingANDdecreasing_only_reactions["Reaction names"][z])


    i=0
    
    while i <1343:
        if boolean_findings[i] ==True:
        
            l= p2.iloc[i, 0]
            increasingANDdecreasing_only_reactions_gene_names.append(l)
        i=i+1
    
    z=z+1

increasingANDdecreasing_only_reactions_gene_names
# Out:
# ['Cdh',
#  'GlmS',
#  'PldB',
#  'FolK',
#  'Ppk',
#  'Aas',
#  'SpoT',
#  'AdiA',
#  'SpeA',
#  'Adk',
#  'Ndk',
#  'Aas',
#  'AcpP',
#  'Aas',
#  'YchM',
#  'FhuF',
#  'MurA',
#  'S0001',
#  'GlpF',
#  'ThrA',
#  'MetL',
#  'ArgE',
#  'AspC',
#  'ArgH',
#  'Gmk',
#  'Mpl',
#  'GuaD',
#  'Tmk',
#  'PurH',
#  'Fes',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'AmpD',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'GlmU',
#  'PurC',
#  'YbiV',
#  'PldB',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'SsuE',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'UshA',
#  'AllA',
#  'LdcA',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'ProC',
#  'PurH',
#  'Adk',
#  'Ndk',
#  'PurD',
#  'FabI',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'MsbA',
#  'TesB',
#  'UgpA',
#  'UgpB',
#  'UgpE',
#  'UgpC',
#  'Ppc',
#  'Dfp',
#  'Pck',
#  'ScpC',
#  'FolD',
#  'CysE',
#  'PgpB',
#  'PgpA',
#  'TesB',
#  'AceA',
#  'S0001',
#  'ZupT',
#  'PldB',
#  'NadK',
#  'Tdk',
#  'MsbA',
#  'Adk',
#  'Ndk',
#  'ZupT',
#  'Fre',
#  'CysI',
#  'CysJ',
#  'Aas',
#  'AcpP',
#  'PgpB',
#  'BacA',
#  'YbjG',
#  'IspU',
#  'SpeC',
#  'SpeF',
#  'AcpH',
#  'GhrB',
#  'GhrA',
#  'Aas',
#  'Dld',
#  'LdhA',
#  'Eno',
#  'CysI',
#  'CysJ',
#  'Cmk',
#  'PyrH',
#  'MsbA',
#  'GapA',
#  'TdcE',
#  'PflA',
#  'YfiD',
#  'PflB',
#  'PflD',
#  'PflC',
#  'Cdh',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'CycA',
#  'NadD',
#  'GuaA',
#  'ZitB',
#  'FieF',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GhrB',
#  'ActP',
#  'Lpd',
#  'GlcA',
#  'LldP',
#  'GcvP',
#  'GcvT',
#  'GcvH',
#  'GhrA',
#  'AsnA',
#  'PldB',
#  'GpsA',
#  'Asd',
#  'Tmk',
#  'ThiL',
#  'FabB',
#  'FabF',
#  'PurF',
#  'GldA',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'TesB',
#  'Deleted',
#  'GadB',
#  'CynT',
#  'Can',
#  'Gpt',
#  'Adk',
#  'PurL',
#  'AtpC',
#  'AtpD',
#  'AtpB',
#  'AtpF',
#  'AtpE',
#  'AtpG',
#  'AtpA',
#  'AtpI',
#  'AtpH',
#  'S0001',
#  'AmtB',
#  'FabI',
#  'Fre',
#  'GdhA',
#  'DacB',
#  'PbpG',
#  'MepA',
#  'Kbl',
#  'LdcA',
#  'IdnK',
#  'GntK',
#  'Aas',
#  'YccX',
#  'MurI',
#  'GlpQ',
#  'AraE',
#  'YdeA',
#  'GlyA',
#  'Psd',
#  'ZupT',
#  'CorA',
#  'AccA',
#  'AccC',
#  'AccD',
#  'AccB',
#  'Gmm',
#  'ZupT',
#  'DdlA',
#  'DdlB',
#  'Alr',
#  'DadX',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'CysH',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'LdcA',
#  'RpiB',
#  'RpiA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'AcpH',
#  'Psd',
#  'GlpT',
#  'DcuA',
#  'DcuB',
#  'DcuC',
#  'AstC',
#  'ArgD',
#  'CysN',
#  'CysD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'RihC',
#  'NupC',
#  'NupG',
#  'Cdd',
#  'RihA',
#  'RihB',
#  'Udk',
#  'PurB',
#  'FabI',
#  'Cdh',
#  'PotE',
#  'PuuP',
#  'FhuF',
#  'Deleted',
#  'IlvA',
#  'Aas',
#  'YccX',
#  'TpiA',
#  'SstT',
#  'TesB',
#  'YccX',
#  'PldB',
#  'YahI',
#  'YbcF',
#  'YqeA',
#  'GlpK',
#  'PitA',
#  'PitB',
#  'GrxB',
#  'CysH',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'Aas',
#  'AcpP',
#  'Cmk',
#  'Pgk',
#  'AceB',
#  'GlcB',
#  'GlmM',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'FabI',
#  'AmpD',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'Cdh',
#  'PurU',
#  'Gnd',
#  'AcnA',
#  'AcnB',
#  'PgpB',
#  'PgpA',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Acs',
#  'EamA',
#  'EamB',
#  'PabA',
#  'PabB',
#  'EntD',
#  'SpeE',
#  'GltA',
#  'CodA',
#  'CodB',
#  'PuuA',
#  'GlgA',
#  'ScpC',
#  'PurC',
#  'MenH',
#  'MenD',
#  'MsbA',
#  'CysQ',
#  'ArgG',
#  'ThrA',
#  'LysC',
#  'MetL',
#  'TesB',
#  'IdnD',
#  'MurD',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'PldB',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'FolD',
#  'RihC',
#  'RihA',
#  'RihB',
#  'GlpX',
#  'YggF',
#  'Fbp',
#  'Adk',
#  'Ndk',
#  'Aas',
#  'PurA',
#  'LpxB',
#  'Cdh',
#  'MsbA',
#  'FocB',
#  'FocA',
#  'Aas',
#  'Aas',
#  'GsiA',
#  'GsiB',
#  'GsiC',
#  'GsiD',
#  'GalP',
#  'MetC',
#  'TnaA',
#  'IscS',
#  'SufS',
#  'SufE',
#  'MpaA',
#  'Mdh',
#  'Mqo',
#  'CysC',
#  'FabI',
#  'NagZ',
#  'Aas',
#  'PyrG',
#  'Cmk',
#  'ZitB',
#  'FieF',
#  'S0001',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'DctA',
#  'DcuA',
#  'DcuB',
#  'FumB',
#  'FumC',
#  'FumA',
#  'DcuC',
#  'Udp',
#  'YccX',
#  'TrkA',
#  'Kch',
#  'SapD',
#  'TrkH',
#  'Kup',
#  'TrkG',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'IspH',
#  'PpsA',
#  'Prs',
#  'LeuA',
#  'MurB',
#  'YccX',
#  'CysM',
#  'CysK',
#  'CsdA',
#  'SelA',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'MsbA',
#  'Deleted',
#  'MltC',
#  'EmtA',
#  'MltB',
#  'Slt',
#  'MltA',
#  'GldA',
#  'DdpA',
#  'DdpB',
#  'DdpD',
#  'DdpC',
#  'DppF',
#  'DdpF',
#  'DppB',
#  'DppD',
#  'DppA',
#  'DppC',
#  'ThiD',
#  'MgsA',
#  'MsbA',
#  'TesB',
#  'AmpD',
#  'AmiC',
#  'AmiB',
#  'AmiA',
#  'KatE',
#  'KatG',
#  'Maa',
#  'PurM',
#  'FabI',
#  'TesB',
#  'SpoT',
#  'RelA',
#  'PldB',
#  'Deleted',
#  'Rpe',
#  'GuaB',
#  'ArgE',
#  'S0001',
#  'CyoC',
#  'CyoB',
#  'CyoD',
#  'CyoA',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'AcpP',
#  'FabD',
#  'DctA',
#  'TalB',
#  'TalA',
#  'CdsA',
#  'EamA',
#  'EamB',
#  'ZitB',
#  'FieF',
#  'Cdh',
#  'AcnA',
#  'AcnB',
#  'Aas',
#  'AcpP',
#  'NadE',
#  'PldB',
#  'ArgA',
#  'PlsC',
#  'ArgC',
#  'Deleted',
#  'ArgI',
#  'Adk',
#  'Ndk',
#  'PldB',
#  'DeoD',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Pgl',
#  'Gph',
#  'DeoD',
#  'DeoA',
#  'ThrB',
#  'XdhA',
#  'XdhB',
#  'XdhC',
#  'PldB',
#  'CpdB',
#  'AphA',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'ArgB',
#  'MurE',
#  'CdsA',
#  'PuuA',
#  'GlnA',
#  'MurF',
#  'Aas',
#  'PykA',
#  'PykF',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'S0001',
#  'AqpZ',
#  'PssA',
#  'Pck',
#  'Cdh',
#  'AmpG',
#  'GrxB',
#  'TrxA',
#  'TrxC',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdA',
#  'NrdB',
#  'NrdF',
#  'NrdE',
#  'FldB',
#  'FldA',
#  'YdbK',
#  'FabI',
#  'MurG',
#  'PutA',
#  'ZitB',
#  'FieF',
#  'FabG',
#  'PldB',
#  'MsbA',
#  'XylA',
#  'Fes',
#  'PhoE',
#  'OmpC',
#  'OmpF',
#  'OmpN',
#  'Adk',
#  'Ndk',
#  'Sad',
#  'GabD',
#  'NadD',
#  'NadR',
#  'FabB',
#  'PgpB',
#  'PgpA',
#  'Deleted',
#  'MltC',
#  'EmtA',
#  'MltB',
#  'Slt',
#  'MltA',
#  'Aas',
#  'AcpP',
#  'AcpP',
#  'PlsX',
#  'YccX',
#  'DeoD',
#  'Deleted',
#  'DeoD',
#  'Tdk',
#  'Udk',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'GrxB',
#  'GrxD',
#  'GrxC',
#  'GrxA',
#  'NrdF',
#  'NrdE',
#  'FhuF',
#  'PurE',
#  'ZupT',
#  'Dcd',
#  'PldB',
#  'PgpB',
#  'PgpA',
#  'YdjI',
#  'FbaB',
#  'FbaA',
#  'Gmk',
#  'Aas',
#  'AcpP',
#  'Icd',
#  'PgpB',
#  'PgpA',
#  'ThrC',
#  'GlmU',
#  'MsbA',
#  'AphA',
#  'SurE',
#  'UshA',
#  'AcpP',
#  'PlsX',
#  'OppF',
#  'OppB',
#  'OppC',
#  'OppD',
#  'OppA',
#  'PldB',
#  'PurB',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'Aas',
#  'TktB',
#  'TktA',
#  'PldB',
#  'FrlA',
#  'LysP',
#  'PgpB',
#  'PgpA',
#  'Lpd',
#  'SucB',
#  'SucA',
#  'FabI',
#  'Deleted',
#  'DeoD',
#  'PssA',
#  'TreC',
#  'Aas',
#  'TesB',
#  'FabI',
#  'PutA',
#  'YtjC',
#  'GpmA',
#  'GpmM',
#  'YqaB',
#  'Pgm',
#  'Aas',
#  'PlsY',
#  'PurK',
#  'PlsY',
#  'PgpB',
#  'PgpA',
#  'MraY',
#  'PurN',
#  'Aas',
#  'AcpP',
#  'PlsC',
#  'GuaC',
#  'FldB',
#  'FldA',
#  'Fpr',
#  'NrdD',
#  'NrdG',
#  'FsaA',
#  'FsaB',
#  'YccX',
#  'Aas',
#  'DctA',
#  'CorA',
#  'TesB',
#  'AphA',
#  'YfbR',
#  'SurE',
#  'YjjG',
#  'UshA',
#  'TktB',
#  'TktA',
#  'MurC']

# %%
Ushaped_gene_names = list( dict.fromkeys(Ushaped_gene_names) ) #remove duplicates in the list. I think that you convert it to dictionary and back to list (not sure)
one_gene_names = list( dict.fromkeys(one_gene_names) )
flat_gene_names = list( dict.fromkeys(flat_gene_names) )
saturated_gene_names = list( dict.fromkeys(saturated_gene_names) )
monotonically_increasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_increasingANDstable_reactions_gene_names) )
monotonically_increasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_increasing_only_reactions_gene_names) )
monotonically_decreasingANDstable_reactions_gene_names = list( dict.fromkeys(monotonically_decreasingANDstable_reactions_gene_names) )
monotonically_decreasing_only_reactions_gene_names = list( dict.fromkeys(monotonically_decreasing_only_reactions_gene_names) )
increasingANDdecreasingANDstable_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasingANDstable_reactions_gene_names) )
increasingANDdecreasing_only_reactions_gene_names = list( dict.fromkeys(increasingANDdecreasing_only_reactions_gene_names) )

d1= pd.DataFrame(Ushaped_gene_names, columns= ["Gene names for Ushaped reactions"])
d2= pd.DataFrame(one_gene_names, columns= ["Gene names for reactions with one feasible value"])
d3= pd.DataFrame(flat_gene_names, columns= ["Gene names for flat reactions"])
d4= pd.DataFrame(saturated_gene_names, columns= ["Gene names for saturating reactions"])
d5= pd.DataFrame(monotonically_increasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and stable reactions"])
d6= pd.DataFrame(monotonically_increasing_only_reactions_gene_names, columns= ["Gene names for increasing only reactions"])
d7= pd.DataFrame(monotonically_decreasingANDstable_reactions_gene_names, columns= ["Gene names for decreasing and stable reactions"])
d8= pd.DataFrame(monotonically_decreasing_only_reactions_gene_names, columns= ["Gene names for decreasing only reactions"])
d9= pd.DataFrame(increasingANDdecreasingANDstable_reactions_gene_names, columns= ["Gene names for increasing and decreasing and stable reactions"])
d10= pd.DataFrame(increasingANDdecreasing_only_reactions_gene_names, columns= ["Gene names for increasing and decreasing only reactions"])

csv_Ushaped_gene_names = d1.to_csv('Ushaped_gene_names.csv', index = True)
csv_one_gene_names = d2.to_csv('one_gene_names.csv', index = True) 
csv_flat_gene_names = d3.to_csv('flat_gene_names.csv', index = True)
csv_saturated_gene_names = d4.to_csv('saturated_gene_names.csv', index = True)
csv_monotonically_increasingANDstable_reactions_gene_names = d5.to_csv('monotonically_increasingANDstable_reactions_gene_names.csv', index = True)
csv_monotonically_increasing_only_reactions_gene_names = d6.to_csv('monotonically_increasing_only_reactions_gene_names.csv', index = True)
csv_monotonically_decreasingANDstable_reactions_gene_names = d7.to_csv('monotonically_decreasingANDstable_reactions_gene_names.csv', index = True)
csv_monotonically_decreasing_only_reactions_gene_names = d8.to_csv('monotonically_decreasing_only_reactions_gene_names.csv', index = True)
csv_increasingANDdecreasingANDstable_reactions_gene_names = d9.to_csv('increasingANDdecreasingANDstable_reactions_gene_names.csv', index = True)
csv_increasingANDdecreasing_only_reactions_gene_names = d10.to_csv('increasingANDdecreasing_only_reactions_gene_names.csv', index = True)
